# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#PSO
airfoil_random_seed1_PSO=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\airfoil_global_best_list_PSO_second_step_linear_seed2.csv')
print(len(airfoil_random_seed1_PSO))
autompg_random_seed1_PSO=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\autompg_global_best_list_FixedPSO_second_step_linear_seed2.csv')
print(len(airfoil_random_seed1_PSO))
automobile_random_seed1_PSO=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\automobile_global_best_list_FixedPSO_second_step_linear_seed2.csv')
challenger_random_seed1_PSO=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\challenger_global_best_list_PSO_second_step_linear_seed2.csv')

#Improved PSO
airfoil_random_seed1_ImprovedPSO=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\airfoil_global_best_list_improvedPSO_second_step_linear_seed2.csv')
autompg_random_seed1_ImprovedPSO=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\autompg_global_best_list_PSO_second_step_linear_seed2.csv')
automobile_random_seed1_ImprovedPSO=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\automobile_global_best_list_PSO_second_step_linear_seed2.csv')
challenger_random_seed1_ImprovedPSO=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\challenger_global_best_list_improvedPSO_second_step_linear_seed2.csv')

#FA
airfoil_random_seed1_FA=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\current_best_result_list_airfoil_FA_seed2.csv')
autompg_random_seed1_FA=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\current_best_result_list_autompg_FA_seed2.csv')
automobile_random_seed1_FA=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\current_best_result_list_automobile_FA_seed2.csv')
challenger_random_seed1_FA=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\current_best_result_list_challenger_FA_seed2.csv')

#CS
airfoil_random_seed1_CS=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\current_best_list_airfoil_second_step_CS_seed2.csv')
autompg_random_seed1_CS=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\current_best_list_autompg_second_step_CS_seed2.csv')
automobile_random_seed1_CS=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\current_best_list_automobile_second_step_CS_seed2.csv')
challenger_random_seed1_CS=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Thesis Coding\\current_best_list_challenger_second_step_CS_seed2.csv')
# Out:
# 99
# 99

# %%
#airfoil plotting
fig=plt.figure(figsize=(20,7))
fig.suptitle('Dataset 1 Airfoil')
for i in range(3):
    if i == 0:
        score= i+1
        ax1=fig.add_subplot(1,3,score)
        FPSO=airfoil_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax1)
        PSO=airfoil_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax1)
        FA=airfoil_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax1)
        CS=airfoil_random_seed1_CS.iloc[:,i].plot(kind='line',color='green', label='CS', ax=ax1)
        #ax1.set_xlabel("iteration")
        ax1.set_title('Training Loss')
        ax1.set_ylabel("MSE")
        ax1.legend()
    if i == 1:
        score= i+1
        ax2=fig.add_subplot(1,3,score)
        PSO=airfoil_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax2)
        FA=airfoil_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax2)
        CS=airfoil_random_seed1_CS.iloc[:,i].plot(kind='line',color='green', label='CS', ax=ax2)
        #ax2.set_xlabel("iteration")
        ax2.set_title('Validation Loss')
        ax2.set_ylabel("MSE")
        ax2.legend()
    if i == 2:
        score= i+1
        ax3=fig.add_subplot(1,3,score)
        PSO=airfoil_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax3)
        FA=airfoil_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax3)
        CS=airfoil_random_seed1_CS.iloc[:,i].plot(kind='line',color='green', label='CS', ax=ax3)
        #ax3.set_xlabel("iteration")
        ax3.set_title('Testing Loss')
        ax3.set_ylabel("MSE")
        ax3.legend()
        
fig.savefig('C:\\Users\\user\\Desktop\\Thesis\\airfoil_random_seed1_plot.jpg')

# %%
#autompg plotting
fig=plt.figure(figsize=(20,7))
fig.suptitle('Dataset 2 Autompg')
for i in range(3):
    if i == 0:
        score= i+1
        ax1=fig.add_subplot(1,3,score)
        PSO=autompg_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax1)
        FA=autompg_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax1)
        CS=autompg_random_seed1_CS.iloc[:,i].plot(kind='line',color='green', label='CS', ax=ax1)
        #ax1.set_xlabel("iteration")
        ax1.set_title('Training Loss')
        ax1.set_ylabel("MSE")
        ax1.legend()
    if i == 1:
        score= i+1
        ax2=fig.add_subplot(1,3,score)
        PSO=autompg_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax2)
        FA=autompg_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax2)
        CS=autompg_random_seed1_CS.iloc[:,i].plot(kind='line',color='green', label='CS', ax=ax2)
        #ax2.set_xlabel("iteration")
        ax2.set_title('Validation Loss')
        ax2.set_ylabel("MSE")
        ax2.legend()
    if i == 2:
        score= i+1
        ax3=fig.add_subplot(1,3,score)
        PSO=autompg_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax3)
        FA=autompg_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax3)
        CS=autompg_random_seed1_CS.iloc[:,i].plot(kind='line',color='green', label='CS', ax=ax3)
        #ax3.set_xlabel("iteration")
        ax3.set_title('Testing Loss')
        ax3.set_ylabel("MSE")
        ax3.legend()
    
fig.savefig('C:\\Users\\user\\Desktop\\Thesis\\autompg_random_seed1_plot.jpg')

# %%
#automobile plotting
fig=plt.figure(figsize=(20,7))
fig.suptitle('Dataset 3 Automobile')
for i in range(3):
    if i == 0:
        score= i+1
        ax1=fig.add_subplot(1,3,score)
        PSO=automobile_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax1)
        FA=automobile_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax1)
        CS=automobile_random_seed1_CS.iloc[:,i].plot(kind='line',color='green', label='CS', ax=ax1)
        #ax1.set_xlabel("iteration")
        ax1.set_title('Training Loss')
        ax1.set_ylabel("MSE")
        ax1.legend()
    if i == 1:
        score= i+1
        ax2=fig.add_subplot(1,3,score)
        PSO=automobile_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax2)
        FA=automobile_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax2)
        CS=automobile_random_seed1_CS.iloc[:,i].plot(kind='line',color='green', label='CS', ax=ax2)
        #ax2.set_xlabel("iteration")
        ax2.set_title('Validation Loss')
        ax2.set_ylabel("MSE")
        ax2.legend()
    if i == 2:
        score= i+1
        ax3=fig.add_subplot(1,3,score)
        PSO=automobile_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax3)
        FA=automobile_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax3)
        CS=automobile_random_seed1_CS.iloc[:,i].plot(kind='line',color='green', label='CS', ax=ax3)
        #ax3.set_xlabel("iteration")
        ax3.set_title('Testing Loss')
        ax3.set_ylabel("MSE")
        ax3.legend()
    
fig.savefig('C:\\Users\\user\\Desktop\\Thesis\\automobile_random_seed1_plot.jpg')

# %%
#wdbc plotting
fig=plt.figure(figsize=(20,7))
fig.suptitle('Dataset 4 Breast Cancer')
for i in range(3):
    if i == 0:
        score= i+1
        ax1=fig.add_subplot(1,3,score)
        PSO=wdbc_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax1)
        FA=wdbc_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax1)
        CS=wdbc_random_seed1_CS.iloc[:,i].plot(kind='line',color='green', label='CS', ax=ax1)
        #ax1.set_xlabel("iteration")
        ax1.set_title('Training Loss')
        ax1.set_ylabel("MSE")
        ax1.legend()
    if i == 1:
        score= i+1
        ax2=fig.add_subplot(1,3,score)
        PSO=wdbc_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax2)
        FA=wdbc_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax2)
        CS=wdbc_random_seed1_CS.iloc[:,i].plot(kind='line',color='green', label='CS', ax=ax2)
        #ax2.set_xlabel("iteration")
        ax2.set_title('Validation Loss')
        ax2.set_ylabel("MSE")
        ax2.legend()
    if i == 2:
        score= i+1
        ax3=fig.add_subplot(1,3,score)
        PSO=wdbc_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax3)
        FA=wdbc_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax3)
        CS=wdbc_random_seed1_CS.iloc[:,i].plot(kind='line',color='green', label='CS', ax=ax3)
        #ax3.set_xlabel("iteration")
        ax3.set_title('Testing Loss')
        ax3.set_ylabel("MSE")
        ax3.legend()
    
fig.savefig('C:\\Users\\user\\Desktop\\Thesis\\wdbc_random_seed1_plot.jpg')

# %%
#challenger plotting
fig=plt.figure(figsize=(20,7))
fig.suptitle('Dataset 5 Challenger')
for i in range(3):
    if i == 0:
        score= i+1
        ax1=fig.add_subplot(1,3,score)
        PSO=challenger_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax1)
        FA=challenger_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax1)
        CS=challenger_random_seed1_CS.iloc[:,i].plot(kind='line',color='green', label='CS', ax=ax1)
        #ax1.set_xlabel("iteration")
        ax1.set_title('Training Loss')
        ax1.set_ylabel("MSE")
        ax1.legend()
    if i == 1:
        score= i+1
        ax2=fig.add_subplot(1,3,score)
        PSO=challenger_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax2)
        FA=challenger_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax2)
        CS=challenger_random_seed1_CS.iloc[:,i].plot(kind='line',color='green', label='CS', ax=ax2)
        #ax2.set_xlabel("iteration")
        ax2.set_title('Validation Loss')
        ax2.set_ylabel("MSE")
        ax2.legend()
    if i == 2:
        score= i+1
        ax3=fig.add_subplot(1,3,score)
        PSO=challenger_random_seed1_PSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax3)
        FA=challenger_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax3)
        CS=challenger_random_seed1_CS.iloc[:,i].plot(kind='line',color='green', label='CS', ax=ax3)
        #ax3.set_xlabel("iteration")
        ax3.set_title('Testing Loss')
        ax3.set_ylabel("MSE")
        ax3.legend()
    
fig.savefig('C:\\Users\\user\\Desktop\\Thesis\\challenger_random_seed1_plot.jpg')

# %%
fig=plt.figure(figsize=(20,30))
for i in range(15):
    #airfoil
    if i <= 2:
        #fig.suptitle('Dataset 1 Airfoil')
        if i == 0:
            score= i+1
            ax1=fig.add_subplot(5,3,score)
            FPSO=airfoil_random_seed1_PSO.iloc[:,i].plot(kind='line',color='black', label='FPSO', ax=ax1)
            PSO=airfoil_random_seed1_ImprovedPSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax1)
            FA=airfoil_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax1)
            CS=airfoil_random_seed1_CS.iloc[:,i].plot(kind='line',color='orange', label='CS', ax=ax1)
            #ax1.set_xlabel("iteration")
            ax1.set_title('Training Loss Airfoil', fontsize=16)
            ax1.set_xlabel("Iteration", fontsize=16)
            ax1.set_ylabel("MSE", fontsize=16)
            ax1.legend()
        if i == 1:
            score= i+1
            ax2=fig.add_subplot(5,3,score)
            FPSO=airfoil_random_seed1_PSO.iloc[:,i].plot(kind='line',color='black', label='FPSO', ax=ax2)
            PSO=airfoil_random_seed1_ImprovedPSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax2)
            FA=airfoil_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax2)
            CS=airfoil_random_seed1_CS.iloc[:,i].plot(kind='line',color='orange', label='CS', ax=ax2)
            #ax2.set_xlabel("iteration")
            ax2.set_title('Validation Loss Airfoil', fontsize=16)
            ax2.set_xlabel("Iteration", fontsize=16)
            ax2.set_ylabel("MSE", fontsize=16)
            ax2.legend()
        if i == 2:
            score= i+1
            ax3=fig.add_subplot(5,3,score)
            FPSO=airfoil_random_seed1_PSO.iloc[:,i].plot(kind='line',color='black', label='FPSO', ax=ax3)
            PSO=airfoil_random_seed1_ImprovedPSO.iloc[:,i].plot(kind='line',color='blue', label='PSO', ax=ax3)
            FA=airfoil_random_seed1_FA.iloc[:,i].plot(kind='line',color='red', label='FA', ax=ax3)
            CS=airfoil_random_seed1_CS.iloc[:,i].plot(kind='line',color='orange', label='CS', ax=ax3)
            #ax3.set_xlabel("iteration")
            ax3.set_title('Testing Loss Airfoil', fontsize=16)
            ax3.set_xlabel("Iteration", fontsize=16)
            ax3.set_ylabel("MSE", fontsize=16)
            ax3.legend()
    #autompg
    if 3 <= i <= 5:    
        #plt.figtext(0.5, 0.5, 'Dataset 1 Autompg', ha='center', va='center')
        if i == 3:
            score= i+1
            ax1=fig.add_subplot(5,3,score)
            FPSO=autompg_random_seed1_PSO.iloc[:,i-3].plot(kind='line',color='black', label='FPSO', ax=ax1)
            PSO=autompg_random_seed1_ImprovedPSO.iloc[:,i-3].plot(kind='line',color='blue', label='PSO', ax=ax1)
            FA=autompg_random_seed1_FA.iloc[:,i-3].plot(kind='line',color='red', label='FA', ax=ax1)
            CS=autompg_random_seed1_CS.iloc[:,i-3].plot(kind='line',color='orange', label='CS', ax=ax1)
            #ax1.set_xlabel("iteration")
            ax1.set_title('Training Loss Autompg', fontsize=16)
            ax1.set_xlabel("Iteration", fontsize=16)
            ax1.set_ylabel("MSE", fontsize=16)
            ax1.legend()
        if i == 4:
            score= i+1
            ax2=fig.add_subplot(5,3,score)
            FPSO=autompg_random_seed1_PSO.iloc[:,i-3].plot(kind='line',color='black', label='FPSO', ax=ax2)
            PSO=autompg_random_seed1_ImprovedPSO.iloc[:,i-3].plot(kind='line',color='blue', label='PSO', ax=ax2)
            FA=autompg_random_seed1_FA.iloc[:,i-3].plot(kind='line',color='red', label='FA', ax=ax2)
            CS=autompg_random_seed1_CS.iloc[:,i-3].plot(kind='line',color='orange', label='CS', ax=ax2)
            #ax2.set_xlabel("iteration")
            ax2.set_title('Validation Loss Autompg', fontsize=16)
            ax2.set_xlabel("Iteration", fontsize=16)
            ax2.set_ylabel("MSE", fontsize=16)
            ax2.legend()
        if i == 5:
            score= i+1
            ax3=fig.add_subplot(5,3,score)
            FPSO=autompg_random_seed1_PSO.iloc[:,i-3].plot(kind='line',color='black', label='FPSO', ax=ax3)
            PSO=autompg_random_seed1_ImprovedPSO.iloc[:,i-3].plot(kind='line',color='blue', label='PSO', ax=ax3)
            FA=autompg_random_seed1_FA.iloc[:,i-3].plot(kind='line',color='red', label='FA', ax=ax3)
            CS=autompg_random_seed1_CS.iloc[:,i-3].plot(kind='line',color='orange', label='CS', ax=ax3)
            #ax3.set_xlabel("iteration")
            ax3.set_title('Testing Loss Autompg', fontsize=16)
            ax3.set_xlabel("Iteration", fontsize=16)
            ax3.set_ylabel("MSE", fontsize=16)
            ax3.legend()
    #automobile
    if 6 <= i <= 8: 
        #fig.suptitle('Dataset 1 Automobile')
        if i == 6:
            score= i+1
            ax1=fig.add_subplot(5,3,score)
            FPSO=automobile_random_seed1_PSO.iloc[:,i-6].plot(kind='line',color='black', label='FPSO', ax=ax1)
            PSO=automobile_random_seed1_ImprovedPSO.iloc[:,i-6].plot(kind='line',color='blue', label='PSO', ax=ax1)
            FA=automobile_random_seed1_FA.iloc[:,i-6].plot(kind='line',color='red', label='FA', ax=ax1)
            CS=automobile_random_seed1_CS.iloc[:,i-6].plot(kind='line',color='orange', label='CS', ax=ax1)
            #ax1.set_xlabel("iteration")
            ax1.set_title('Training Loss Automobile', fontsize=16)
            ax1.set_xlabel("Iteration", fontsize=16)
            ax1.set_ylabel("MSE", fontsize=16)
            ax1.legend()
        if i == 7:
            score= i+1
            ax2=fig.add_subplot(5,3,score)
            FPSO=automobile_random_seed1_PSO.iloc[:,i-6].plot(kind='line',color='black', label='FPSO', ax=ax2)
            PSO=automobile_random_seed1_ImprovedPSO.iloc[:,i-6].plot(kind='line',color='blue', label='PSO', ax=ax2)
            FA=automobile_random_seed1_FA.iloc[:,i-6].plot(kind='line',color='red', label='FA', ax=ax2)
            CS=automobile_random_seed1_CS.iloc[:,i-6].plot(kind='line',color='orange', label='CS', ax=ax2)
            #ax2.set_xlabel("iteration")
            ax2.set_title('Validation Loss Automobile', fontsize=16)
            ax2.set_xlabel("Iteration", fontsize=16)
            ax2.set_ylabel("MSE", fontsize=16)
            ax2.legend()
        if i == 8:
            score= i+1
            ax3=fig.add_subplot(5,3,score)
            FPSO=automobile_random_seed1_PSO.iloc[:,i-6].plot(kind='line',color='black', label='FPSO', ax=ax3)
            PSO=automobile_random_seed1_ImprovedPSO.iloc[:,i-6].plot(kind='line',color='blue', label='PSO', ax=ax3)
            FA=automobile_random_seed1_FA.iloc[:,i-6].plot(kind='line',color='red', label='FA', ax=ax3)
            CS=automobile_random_seed1_CS.iloc[:,i-6].plot(kind='line',color='orange', label='CS', ax=ax3)
            #ax3.set_xlabel("iteration")
            ax3.set_title('Testing Loss Automobile', fontsize=16)
            ax3.set_xlabel("Iteration", fontsize=16)
            ax3.set_ylabel("MSE", fontsize=16)
            ax3.legend()
    #challenger
    if 9 <= i <= 11:
        #fig.suptitle('Dataset 1 challenger')
        if i == 9:
            score= i+1
            ax1=fig.add_subplot(5,3,score)
            FPSO=challenger_random_seed1_PSO.iloc[:,i-9].plot(kind='line',color='black', label='FPSO', ax=ax1)
            PSO=challenger_random_seed1_ImprovedPSO.iloc[:,i-9].plot(kind='line',color='blue', label='PSO', ax=ax1)
            FA=challenger_random_seed1_FA.iloc[:,i-9].plot(kind='line',color='red', label='FA', ax=ax1)
            CS=challenger_random_seed1_CS.iloc[:,i-9].plot(kind='line',color='orange', label='CS', ax=ax1)
            #ax1.set_xlabel("iteration")
            ax1.set_title('Training Loss Challenger', fontsize=16)
            ax1.set_xlabel("Iteration", fontsize=16)
            ax1.set_ylabel("MSE", fontsize=16)
            ax1.legend()
        if i == 10:
            score= i+1
            ax2=fig.add_subplot(5,3,score)
            FPSO=challenger_random_seed1_PSO.iloc[:,i-9].plot(kind='line',color='black', label='FPSO', ax=ax2)
            PSO=challenger_random_seed1_ImprovedPSO.iloc[:,i-9].plot(kind='line',color='blue', label='PSO', ax=ax2)
            FA=challenger_random_seed1_FA.iloc[:,i-9].plot(kind='line',color='red', label='FA', ax=ax2)
            CS=challenger_random_seed1_CS.iloc[:,i-9].plot(kind='line',color='orange', label='CS', ax=ax2)
            #ax2.set_xlabel("iteration")
            ax2.set_title('Validation Loss Challenger', fontsize=16)
            ax2.set_xlabel("Iteration", fontsize=16)
            ax2.set_ylabel("MSE", fontsize=16)
            ax2.legend()
        if i == 11:
            score= i+1
            ax3=fig.add_subplot(5,3,score)
            FPSO=challenger_random_seed1_PSO.iloc[:,i-9].plot(kind='line',color='black', label='FPSO', ax=ax3)
            PSO=challenger_random_seed1_ImprovedPSO.iloc[:,i-9].plot(kind='line',color='blue', label='PSO', ax=ax3)
            FA=challenger_random_seed1_FA.iloc[:,i-9].plot(kind='line',color='red', label='FA', ax=ax3)
            CS=challenger_random_seed1_CS.iloc[:,i-9].plot(kind='line',color='orange', label='CS', ax=ax3)
            #ax3.set_xlabel("iteration")
            ax3.set_title('Testing Loss Challenger', fontsize=16)
            ax3.set_xlabel("Iteration", fontsize=16)
            ax3.set_ylabel("MSE", fontsize=16)
            ax3.legend()
        
fig.savefig('C:\\Users\\user\\Desktop\\Thesis\\all_result_random_seed1_plot_final.jpg')
