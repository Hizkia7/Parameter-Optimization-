# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns
from random import seed

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import  MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import Imputer

from keras.models import Sequential
from keras import models
from keras.layers import Dense, Activation, Dropout, LSTM, BatchNormalization
from keras import layers
from keras import optimizers
from keras import callbacks
# Out:
# Using TensorFlow backend.

# %%
#Generate Dataset
#Airfoil Self-Noise
df_airfoil=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Airfoil_self_noise.csv')

#Automobile
df_automobile=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Automobile_data.txt')

#Autompg
df_autompg=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Auto-mpg.csv')

#ChallengerUSA
df_challenger=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Challenger USA Space Shuttle O-Ring.csv')

#Combine Cycle Power
df_combine=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Combine Cycle Power Plant.csv')

#Computer Hardware
df_computer=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Computer Hardware.csv')

#Concrete Compressive Strength
df_concrete_compressive_strength=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Concrete Compressive Strength.csv')

#Concrete Slump Test
df_concrete1=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Concrete Slump Test.csv')
df_concrete2=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Concrete Slump Test.csv')
df_concrete3=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Concrete Slump Test.csv')

#Energy Efficiency
df_energy1=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Energy Efficiency.csv')
df_energy2=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Energy Efficiency.csv')

#Fertility Diagnosis
df_fertility=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\fertility_Diagnosis.csv')

#Forest Fires
df_forest=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\forestfires.csv')

#Housing
df_housing=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Housing.csv')

#Istanbul Stock Exchange
df_istanbul=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Istanbul Stock Exchange.csv')

#WDBC
df_wdbc=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\wdbc.csv')

# %%
#remove Nan columns of df_energy1
df_energy1=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Energy Efficiency.csv')
df_energy1.drop(df_energy1.columns[11],inplace=True, axis = 1)
df_energy1.drop(df_energy1.columns[10],inplace=True, axis = 1)

#remove Nan columns of df_energy2
df_energy2=pd.read_csv('C:\\Users\\user\\Desktop\\Thesis\\Datasets\\Energy Efficiency.csv')
df_energy2.drop(df_energy2.columns[11],inplace=True, axis = 1)
df_energy2.drop(df_energy2.columns[10],inplace=True, axis = 1)

#remove question marks
#df_automobile
imp= Imputer(missing_values="NaN", strategy="mean")
df_automobile=df_automobile.replace("?", np.NaN)
df_automobile['num-of-doors'] = df_automobile['num-of-doors'].fillna("four")
for i in df_automobile.columns:
    if df_automobile[i].isnull().sum()>0:
        df_automobile[i]=imp.fit_transform(df_automobile[[i]])
#df_automobile = df_automobile[(df_automobile.astype(str) != '?').all(axis=1)]
#df_automobile.reset_index(drop=True, inplace=True)
df_automobile = df_automobile.drop(['engine-location'], axis=1)
#df_autompg
df_autompg = df_autompg[(df_autompg.astype(str) != '?').all(axis=1)]
df_autompg.reset_index(drop=True, inplace=True)

#convert string to number
le=LabelEncoder()
#df_automobile
string_automobile=df_automobile[['make','fuel-type','aspiration','num-of-doors', 'body-style', 'drive-wheels', 'engine-type', 'num-of-cylinders', 'fuel-system']]
df_automobile[['make','fuel-type','aspiration','num-of-doors', 'body-style', 'drive-wheels', 'engine-type', 'num-of-cylinders', 'fuel-system']]=string_automobile.apply(le.fit_transform)
encoder=df_automobile[['make','fuel-type','aspiration','num-of-doors', 'body-style', 'drive-wheels', 'engine-type', 'num-of-cylinders', 'fuel-system']].astype(np.int64)
df_automobile[['make','fuel-type','aspiration','num-of-doors', 'body-style', 'drive-wheels', 'engine-type', 'num-of-cylinders', 'fuel-system']]=encoder
a=df_automobile[['normalized-losses','horsepower','price']].astype(np.int64)
b=df_automobile[['bore','stroke','peak-rpm']].astype(float)
df_automobile[['normalized-losses','horsepower','price']]=a
df_automobile[['bore','stroke','peak-rpm']]=b
#df_computer
string_computer=df_computer[['Vendor','Model']]
df_computer[['Vendor','Model']]=string_computer.apply(le.fit_transform)
df_computer[['Vendor','Model']]=df_computer[['Vendor','Model']].astype(np.int64)

#dropna spesific column & special preprocessing
#df_forest
df_forest=df_forest[(df_forest['area'].astype(int) != 0)] 
df_forest.reset_index(drop=True, inplace=True)
num_features=10
dimension=(num_features+1)*9+10
population_size=(2*dimension+1)*2
df_forest=df_forest[:population_size]
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
def preprocessing_data1(df,num_features):
    dimension=(num_features+1)*9+10
    population_size=(2*dimension+1)*2
    df=df.dropna()
    df=df[:population_size]
    df
    return df

# %%
def train_test_split1(x, y):
    x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.15, random_state=42)
    return x_train, x_test, y_train, y_test

# %%
def preprocessing_data2(df):
    train_size = 0.85*len(df)
    train_size = int(train_size)
    df_train = df[:train_size]
    df_test = df[train_size:]
    print(len(df_test))
    print(len(df_train))
    validation_size=len(df_test)/len(df_train)
    print(validation_size)
    return df_train, df_test, validation_size

# %%
#df_airfoil=preprocessing_data1(df_airfoil,5)
#df_automobile=preprocessing_data1(df_automobile,22)
#df_autompg=preprocessing_data1(df_autompg,7)
#df_challenger=preprocessing_data1(df_challenger,3)
#df_combine=preprocessing_data1(df_combine,4)
#df_computer=preprocessing_data1(df_computer,9)
#df_concrete_compressive_strength=preprocessing_data1(df_concrete_compressive_strength,8)
#df_concrete1=preprocessing_data1(df_concrete1,7)
#df_concrete2=preprocessing_data1(df_concrete2,7)
#df_concrete3=preprocessing_data1(df_concrete3,7)
#df_energy1=preprocessing_data1(df_energy1,8)
#df_energy2=preprocessing_data1(df_energy2,8)

#df_fertility=preprocessing_data1(df_fertility,9)
for i in df_fertility:
    df_fertility.Diagnosis[df_fertility.Diagnosis == 'N'] = 1
    df_fertility.Diagnosis[df_fertility.Diagnosis == 'O'] = 2
df_fertility['Diagnosis']=df_fertility['Diagnosis'].astype(np.int64)

#df_forest=preprocessing_data1(df_forest,10)
#df_housing=preprocessing_data1(df_housing,13)

#df_istanbul=preprocessing_data1(df_istanbul,7)
new_header = df_istanbul.iloc[0]
df_istanbul = df_istanbul[1:]
df_istanbul.columns = new_header
df_istanbul[['ISE1','ISE2','SP','DAX','FTSE','NIKKEI','BOVESPA','EU','EM']]=df_istanbul[['ISE1','ISE2','SP','DAX','FTSE','NIKKEI','BOVESPA','EU','EM']].astype(np.float64)


#df_wdbc=preprocessing_data1(df_wdbc,10)
df_wdbc.drop(df_wdbc.columns[0], axis=1, inplace = True)
df_wdbc.columns=['id','diagnosis','radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean','symmetry_mean','fractal_dimension_mean','radius_se','texture_se','perimeter_se','area_se','smoothness_se','compactness_se','concavity_se','concave points_se','symmetry_se','fractal_dimension_se','radius_worst','texture_worst','perimeter_worst','area_worst','smoothness_worst','compactness_worst','concavity_worst','concave points_worst','symmetry_worst','fractal_dimension_worst']
for i in df_wdbc:
    df_wdbc.diagnosis[df_wdbc.diagnosis == 'M'] = 1
    df_wdbc.diagnosis[df_wdbc.diagnosis == 'B'] = 2
df_wdbc['diagnosis']=df_wdbc['diagnosis'].astype(np.object)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# ...

# %%
#Train and Test 17 datasets
#Airfoil
x_airfoil = df_airfoil.drop(['Scaled sound pressure level'], axis = 1)
y_airfoil = df_airfoil['Scaled sound pressure level']
#Wdbc
x_wdbc = df_wdbc[['radius_mean','perimeter_mean','area_mean','concavity_mean','concave points_mean','radius_worst','perimeter_worst','area_worst','concave points_worst']]
y_wdbc = df_wdbc['diagnosis']
labelencoder_Y = LabelEncoder()
y_wdbc = labelencoder_Y.fit_transform(y_wdbc)
#Automobile
x_automobile = df_automobile.drop(['price','make','body-style'], axis = 1)
y_automobile = df_automobile['price']
y_automobile = np.reshape(y_automobile.values, (-1,1))
#Autompg
x_autompg = df_autompg.drop(['Mpg','Car Name'], axis = 1)
y_autompg = df_autompg['Mpg']
#Challenger
x_challenger = df_challenger.drop(['Number of O-rings','Temporal Order of Flight'], axis = 1)
y_challenger = df_challenger['Number of O-rings']
#Combine
x_combine = df_combine.drop(['PE'], axis = 1)
y_combine = df_combine['PE']
y_combine = np.reshape(y_combine.values, (-1,1))
#Computer
x_computer = df_computer.drop(['ERP'], axis = 1)
y_computer = df_computer['ERP']
y_computer = np.reshape(y_computer.values, (-1,1))
#Concrete_compressive_strength
x_concrete_compressive_strength = df_concrete_compressive_strength.drop(['CCS'], axis = 1)
y_concrete_compressive_strength = df_concrete_compressive_strength['CCS']
y_concrete_compressive_strength = np.reshape(y_concrete_compressive_strength.values, (-1,1))
#Concrete1
x_concrete1 = df_concrete1.drop(['No','Compressive Strength (28-day)(Mpa)'], axis = 1)
y_concrete1 = df_concrete1['Compressive Strength (28-day)(Mpa)']
#Concrete2
x_concrete2 = df_concrete2.drop(['No','SLUMP(cm)'], axis = 1)
y_concrete2 = df_concrete2['SLUMP(cm)']
y_concrete2 = np.reshape(y_concrete2.values, (-1,1))
#Concrete3
x_concrete3 = df_concrete3.drop(['No','FLOW(cm)'], axis = 1)
y_concrete3 = df_concrete3['FLOW(cm)']
y_concrete3 = np.reshape(y_concrete3.values, (-1,1))
#Energy1
x_energy1 = df_energy1.drop(['Y1'], axis = 1)
y_energy1 = df_energy1['Y1']
#Energy2
x_energy2 = df_energy2.drop(['Y2'], axis = 1)
y_energy2 = df_energy2['Y2']
#Fertility
x_fertility = df_fertility.drop(['Diagnosis'], axis = 1)
y_fertility = df_fertility['Diagnosis']
#Forest
x_forest = df_forest.drop(['month','day','area'], axis = 1)
y_forest = df_forest['area']
y_forest = np.reshape(y_forest.values, (-1,1))
#Housing
x_housing = df_housing.drop(['MEDV'], axis = 1)
y_housing = df_housing['MEDV']
#Istanbul
x_istanbul = df_istanbul.drop(['date','ISE1','ISE2'], axis = 1)
y_istanbul = df_istanbul[['ISE1','ISE2']]
y_istanbul['mean'] = y_istanbul.mean(axis=1)
y_istanbul = y_istanbul['mean']
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
x_train_airfoil, x_test_airfoil, y_train_airfoil, y_test_airfoil = train_test_split1(x_airfoil, y_airfoil)
x_train_automobile, x_test_automobile, y_train_automobile, y_test_automobile = train_test_split1(x_automobile, y_automobile)
x_train_autompg, x_test_autompg, y_train_autompg, y_test_autompg = train_test_split1(x_autompg, y_autompg)
x_train_challenger, x_test_challenger, y_train_challenger, y_test_challenger = train_test_split1(x_challenger, y_challenger)
x_train_combine, x_test_combine, y_train_combine, y_test_combine = train_test_split1(x_combine, y_combine)
x_train_computer, x_test_computer, y_train_computer, y_test_computer = train_test_split1(x_computer, y_computer)
x_train_concrete_compressive_strength, x_test_concrete_compressive_strength, y_train_concrete_compressive_strength, y_test_concrete_compressive_strength = train_test_split1(x_concrete_compressive_strength, y_concrete_compressive_strength)
x_train_concrete1, x_test_concrete1, y_train_concrete1, y_test_concrete1 = train_test_split1(x_concrete1, y_concrete1)
x_train_concrete2, x_test_concrete2, y_train_concrete2, y_test_concrete2 = train_test_split1(x_concrete2, y_concrete2)
x_train_concrete3, x_test_concrete3, y_train_concrete3, y_test_concrete3 = train_test_split1(x_concrete3, y_concrete3)
x_train_energy1, x_test_energy1, y_train_energy1, y_test_energy1 = train_test_split1(x_energy1, y_energy1)
x_train_energy2, x_test_energy2, y_train_energy2, y_test_energy2 = train_test_split1(x_energy2, y_energy2)
x_train_fertility, x_test_fertility, y_train_fertility, y_test_fertility = train_test_split1(x_fertility, y_fertility)
x_train_forest, x_test_forest, y_train_forest, y_test_forest = train_test_split1(x_forest, y_forest)
x_train_housing, x_test_housing, y_train_housing, y_test_housing = train_test_split1(x_housing, y_housing)
x_train_istanbul, x_test_istanbul, y_train_istanbul, y_test_istanbul = train_test_split1(x_istanbul, y_istanbul)
x_train_wdbc, x_test_wdbc, y_train_wdbc, y_test_wdbc = train_test_split1(x_wdbc, y_wdbc)

# %%
def train_val_split(x_train, y_train):
    X_train, X_val, Y_train, Y_val= train_test_split(x_train, y_train, test_size=0.176, random_state=42)
    return X_train, X_val, Y_train, Y_val

# %%
def standard_scaler(X_train, X_val, x_test):
    sc=StandardScaler()
    X_train=X_train.values
    X_val=X_val.values
    x_test=x_test.values
    X_scale_train=sc.fit(X_train)
    #X_scale_val=sc.fit(X_val)
    #x_scale_test=sc.fit(x_test)
    X_train=X_scale_train.transform(X_train)
    X_val=X_scale_train.transform(X_val)
    x_test=X_scale_train.transform(x_test)
    return X_train, X_val, x_test, X_scale_train

# %%
def min_max_scaler_automobile(X_train, X_val, x_test, Y_train, Y_val, y_test):
    min_max_x=MinMaxScaler()
    min_max_y=MinMaxScaler()
    X_train=X_train.values
    X_val=X_val.values
    x_test=x_test.values
    X_scale_train=min_max_x.fit(X_train)
    #X_scale_val=min_max.fit(X_val)
    #x_scale_test=min_max.fit(x_test)
    Y_scale_train=min_max_y.fit(Y_train)
    #Y_scale_val=min_max.fit(Y_val)
    #y_scale_test=min_max.fit(y_test)
    X_train=X_scale_train.transform(X_train)
    X_val=X_scale_train.transform(X_val)
    x_test=X_scale_train.transform(x_test)
    Y_train=Y_scale_train.transform(Y_train)
    Y_val=Y_scale_train.transform(Y_val)
    y_test=Y_scale_train.transform(y_test)
    return X_train, X_val, x_test, Y_train, Y_val, y_test, X_scale_train, Y_scale_train

# %%
def min_max_scaler(X_train, X_val, x_test, Y_train, Y_val, y_test):
    min_max=MinMaxScaler()
    X_train=X_train.values
    X_val=X_val.values
    x_test=x_test.values
    X_scale_train=min_max.fit(X_train)
    X_scale_val=min_max.fit(X_val)
    x_scale_test=min_max.fit(x_test)
    Y_scale_train=min_max.fit(Y_train)
    Y_scale_val=min_max.fit(Y_val)
    y_scale_test=min_max.fit(y_test)
    X_train=X_scale_train.transform(X_train)
    X_val=X_scale_val.transform(X_val)
    x_test=x_scale_test.transform(x_test)
    Y_train=Y_scale_train.transform(Y_train)
    Y_val=Y_scale_train.transform(Y_val)
    y_test=y_scale_test.transform(y_test)
    return X_train, X_val, x_test, Y_train, Y_val, y_test, min_max

# %%
#Optimizer list
adam0 = 'adam'
adam1 = optimizers.Adam(lr=0.001)
adam2 = optimizers.Adam(lr=0.01)
adam3 = optimizers.Adam(lr=0.0001)
adam4 = optimizers.Adam(lr=0.00001)
sgd = optimizers.SGD(lr=0.005, decay=1e-4, momentum=0.9, nesterov=True)
RMSprop= optimizers.RMSprop(lr=0.001,rho=0.9)
adagrad = optimizers.Adagrad(lr=0.01)
adadelta = optimizers.Adadelta(lr=1.0)

# %%
def NN_model_structure_regression(adam, X_train):
    model = Sequential()
    model.add(Dense(units = 5, input_dim = (X_train.shape[1])))
    model.add(Activation('tanh'))
    #model.add(Dropout(0.2))
    model.add(Dense(units = 10))
    model.add(Activation('linear'))
    model.add(Dense(units = 1))
    model.compile(optimizer = adam , loss = 'mse')
    model.summary()
    #history=model.fit(X_train,Y_train, batch_size=size,epochs=epochs, validation_data=(X_val, Y_val), shuffle=True)
    #evaluate = model.evaluate(x_test, y_test, verbose=2, batch_size=size)
    #print(evaluate)
    return model

# %%
def NN_model_structure_classification(adam, X_train):
    model = Sequential()
    model.add(Dense(units = 5, kernel_initializer = 'uniform', activation = 'relu', input_dim = (X_train.shape[1])))
    #model.add(Activation('relu'))
    #model.add(Dropout(0.2))
    model.add(Dense(units = 10, kernel_initializer = 'uniform', activation = 'relu'))
    #model.add(Activation('sigmoid'))
    model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    model.compile(optimizer = adam , loss = 'binary_crossentropy', metrics=['acc'])
    model.summary()
    #history=model.fit(X_train,Y_train, batch_size=size,epochs=epochs, validation_data=(X_val, Y_val), shuffle=True)
    #evaluate = model.evaluate(x_test, y_test, verbose=2, batch_size=size)
    #print(evaluate)
    return model

# %%
X_train_airfoil, X_val_airfoil, Y_train_airfoil, Y_val_airfoil = train_val_split(x_train_airfoil, y_train_airfoil)
X_train_automobile, X_val_automobile, Y_train_automobile, Y_val_automobile = train_val_split(x_train_automobile, y_train_automobile)
X_train_autompg, X_val_autompg, Y_train_autompg, Y_val_autompg = train_val_split(x_train_autompg, y_train_autompg)
X_train_challenger, X_val_challenger, Y_train_challenger, Y_val_challenger = train_val_split(x_train_challenger, y_train_challenger)
X_train_combine, X_val_combine, Y_train_combine, Y_val_combine = train_val_split(x_train_combine, y_train_combine)
X_train_computer, X_val_computer, Y_train_computer, Y_val_computer = train_val_split(x_train_computer, y_train_computer)
X_train_concrete_compressive_strength, X_val_concrete_compressive_strength, Y_train_concrete_compressive_strength, Y_val_concrete_compressive_strength = train_val_split(x_train_concrete_compressive_strength, y_train_concrete_compressive_strength)
X_train_concrete1, X_val_concrete1, Y_train_concrete1, Y_val_concrete1 = train_val_split(x_train_concrete1, y_train_concrete1)
X_train_concrete2, X_val_concrete2, Y_train_concrete2, Y_val_concrete2 = train_val_split(x_train_concrete2, y_train_concrete2)
X_train_concrete3, X_val_concrete3, Y_train_concrete3, Y_val_concrete3 = train_val_split(x_train_concrete3, y_train_concrete3)
X_train_energy1, X_val_energy1, Y_train_energy1, Y_val_energy1 = train_val_split(x_train_energy1, y_train_energy1)
X_train_energy2, X_val_energy2, Y_train_energy2, Y_val_energy2 = train_val_split(x_train_energy2, y_train_energy2)
X_train_fertility, X_val_fertility, Y_train_fertility, Y_val_fertility = train_val_split(x_train_fertility, y_train_fertility)
X_train_forest, X_val_forest, Y_train_forest, Y_val_forest = train_val_split(x_train_forest, y_train_forest)
X_train_housing, X_val_housing, Y_train_housing, Y_val_housing = train_val_split(x_train_housing, y_train_housing)
X_train_istanbul, X_val_istanbul, Y_train_istanbul, Y_val_istanbul = train_val_split(x_train_istanbul, y_train_istanbul)
X_train_wdbc, X_val_wdbc, Y_train_wdbc, Y_val_wdbc = train_val_split(x_train_wdbc, y_train_wdbc)

# %%
X_train_airfoil, X_val_airfoil, x_test_airfoil, X_scale_train_airfoil=standard_scaler(X_train_airfoil, X_val_airfoil, x_test_airfoil)
#X_train_automobile, X_val_automobile, x_test_automobile=standard_scaler(X_train_automobile, X_val_automobile, x_test_automobile)
#X_train_automobile, X_val_automobile, x_test_automobile, Y_train_automobile, Y_val_automobile, y_test_automobile = normalization(X_train_automobile, X_val_automobile, x_test_automobile, Y_train_automobile, Y_val_automobile, y_test_automobile)
X_train_automobile, X_val_automobile, x_test_automobile, Y_train_automobile, Y_val_automobile, y_test_automobile, X_scale_train_automobile, Y_scale_train_automobile=min_max_scaler_automobile(X_train_automobile, X_val_automobile, x_test_automobile, Y_train_automobile, Y_val_automobile, y_test_automobile)
X_train_autompg, X_val_autompg, x_test_autompg, X_scale_train_autompg=standard_scaler(X_train_autompg, X_val_autompg, x_test_autompg)
X_train_challenger, X_val_challenger, x_test_challenger, X_scale_train_challenger=standard_scaler(X_train_challenger, X_val_challenger, x_test_challenger)
X_train_combine, X_val_combine, x_test_combine, Y_train_combine, Y_val_combine, y_test_combine, min_max_combine=min_max_scaler(X_train_combine, X_val_combine, x_test_combine, Y_train_combine, Y_val_combine, y_test_combine)
X_train_computer, X_val_computer, x_test_computer, Y_train_computer, Y_val_computer, y_test_computer, min_max_computer=min_max_scaler(X_train_computer, X_val_computer, x_test_computer, Y_train_computer, Y_val_computer, y_test_computer)
X_train_concrete_compressive_strength, X_val_concrete_compressive_strength, x_test_concrete_compressive_strength, Y_train_concrete_compressive_strength, Y_val_concrete_compressive_strength, y_test_concrete_compressive_strength, min_max_concrete_compressive_strength=min_max_scaler(X_train_concrete_compressive_strength, X_val_concrete_compressive_strength, x_test_concrete_compressive_strength, Y_train_concrete_compressive_strength, Y_val_concrete_compressive_strength, y_test_concrete_compressive_strength)
X_train_concrete1, X_val_concrete1, x_test_concrete1, X_scale_train_concrete1=standard_scaler(X_train_concrete1, X_val_concrete1, x_test_concrete1)
X_train_concrete2, X_val_concrete2, x_test_concrete2, Y_train_concrete2, Y_val_concrete2, y_test_concrete2, min_max_concrete2=min_max_scaler(X_train_concrete2, X_val_concrete2, x_test_concrete2, Y_train_concrete2, Y_val_concrete2, y_test_concrete2)
X_train_concrete3, X_val_concrete3, x_test_concrete3, Y_train_concrete3, Y_val_concrete3, y_test_concrete3, min_max_concrete3=min_max_scaler(X_train_concrete3, X_val_concrete3, x_test_concrete3, Y_train_concrete3, Y_val_concrete3, y_test_concrete3)
X_train_energy1, X_val_energy1, x_test_energy1, X_scale_train_energy1=standard_scaler(X_train_energy1, X_val_energy1, x_test_energy1)
X_train_energy2, X_val_energy2, x_test_energy2, X_scale_train_energy2=standard_scaler(X_train_energy2, X_val_energy2, x_test_energy2)
X_train_fertility, X_val_fertility, x_test_fertility, X_scale_train_fertility=standard_scaler(X_train_fertility, X_val_fertility, x_test_fertility)
X_train_forest, X_val_forest, x_test_forest, Y_train_forest, Y_val_forest, y_test_forest, min_max_forest=min_max_scaler(X_train_forest, X_val_forest, x_test_forest, Y_train_forest, Y_val_forest, y_test_forest)
X_train_housing, X_val_housing, x_test_housing, X_scale_train_housing=standard_scaler(X_train_housing, X_val_housing, x_test_housing)
X_train_istanbul, X_val_istanbul, x_test_istanbul, X_scale_train_istanbul=standard_scaler(X_train_istanbul, X_val_istanbul, x_test_istanbul)

# %%
def prediction_result_SSE(model,x,y):
    prediction = model.predict(x)
    y_test_list=list(y)
    for i in range(len(y_test_list)):
        print("predict", prediction[i][0], "actual", y_test_list[i])
    square_error_list=[]
    for i in range(len(prediction)):
        square_error=(prediction[i]-y_test_list[i])**2
        square_error_list.append(square_error)
    SSE=(np.sum(square_error_list))/2
    print(SSE)

# %%
def prediction_result_SSE_inverse(model,x,y):
    prediction = model.predict(x)
    prediction = Y_scale_train_automobile.inverse_transform(prediction.reshape(-1,1))
    y=Y_scale_train_automobile.inverse_transform(y)
    y_test_list=list(y)
    for i in range(len(y_test_list)):
        print("predict", prediction[i][0], "actual", y_test_list[i])
    square_error_list=[]
    for i in range(len(prediction)):
        square_error=(prediction[i]-y_test_list[i])**2
        square_error_list.append(square_error)
    SSE=(np.sum(square_error_list))/2
    print(SSE)

# %% [markdown]
# # PSO-MLP

# %%
model_airfoil=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\PSO-MLP_model_airfoil_model_second_step_linear.h5')
training=model_airfoil.evaluate(X_train_airfoil, Y_train_airfoil, verbose=0)
validating=model_airfoil.evaluate(X_val_airfoil, Y_val_airfoil, verbose=0)
testing=model_airfoil.evaluate(x_test_airfoil, y_test_airfoil, verbose=0)
print(training)
print(validating)
print(testing)
# Out:
# WARNING:tensorflow:From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 6.60091209592928
# 8.217971852487988
# 5.95475125734785

# %%
model_autompg=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FixedPSO-MLP_model_autompg_model_second_step_linear.h5')
training=model_autompg.evaluate(X_train_autompg, Y_train_autompg, verbose=0)
validating=model_autompg.evaluate(X_val_autompg, Y_val_autompg, verbose=0)
testing=model_autompg.evaluate(x_test_autompg, y_test_autompg, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 6.78948388134476
# validation 8.64456480640476
# testing 4.976592298281395

# %%
model_automobile=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FixedPSO-MLP_model_automobile_model_second_step.h5')
training=model_automobile.evaluate(X_train_automobile, Y_train_automobile, verbose=0)
validating=model_automobile.evaluate(X_val_automobile, Y_val_automobile, verbose=0)
testing=model_automobile.evaluate(x_test_automobile, y_test_automobile, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 0.008716872095462534
# validation 0.002713445108383894
# testing 0.010148274712264538

# %%
model_challenger=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\PSO-MLP_model_challenger_model_second_step_linear.h5')
training=model_challenger.evaluate(X_train_challenger, Y_train_challenger, verbose=0)
validating=model_challenger.evaluate(X_val_challenger, Y_val_challenger, verbose=0)
testing=model_challenger.evaluate(x_test_challenger, y_test_challenger, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 9.379164112033322e-13
# validation 4.872292890326091e-13
# testing 4.547473508864641e-13

# %%
print('training_data')
prediction_result_SSE(model_airfoil, X_train_airfoil, Y_train_airfoil)
print('validation_data')
prediction_result_SSE(model_airfoil, X_val_airfoil, Y_val_airfoil)
print('testing_data')
prediction_result_SSE(model_airfoil, x_test_airfoil, y_test_airfoil)
# Out:
# training_data
# predict 133.07654 actual 133.59799999999998
# predict 130.45935 actual 131.434
# predict 129.90628 actual 128.679
# predict 126.402405 actual 127.006
# predict 136.09373 actual 134.928
# predict 126.534195 actual 128.139
# predict 128.88606 actual 132.251
# predict 122.197426 actual 127.04
# predict 129.55252 actual 131.515
# predict 135.08809 actual 134.976
# predict 127.75348 actual 129.377
# predict 124.869606 actual 139.226
# predict 116.769684 actual 120.51299999999999
# predict 126.12453 actual 122.235
# predict 134.53844 actual 136.023
# predict 110.07179 actual 110.839
# predict 122.95601 actual 122.771
# predict 121.05549 actual 121.93299999999999
# predict 121.428505 actual 119.67
# predict 125.83824 actual 123.209
# predict 124.45152 actual 128.444
# predict 121.48253 actual 125.62700000000001
# predict 129.56064 actual 128.144
# predict 121.17877 actual 122.75399999999999
# predict 130.14474 actual 130.311
# predict 120.4845 actual 125.715
# ...

# %%
print('training_data')
prediction_result_SSE(model_autompg, X_train_autompg, Y_train_autompg)
print('validation_data')
prediction_result_SSE(model_autompg, X_val_autompg, Y_val_autompg)
print('testing_data')
prediction_result_SSE(model_autompg, x_test_autompg, y_test_autompg)
# Out:
# training_data
# predict 27.016726 actual 27.0
# predict 21.775537 actual 22.0
# predict 23.399572 actual 25.0
# predict 31.539566 actual 30.0
# predict 25.205767 actual 26.8
# predict 25.680643 actual 26.0
# predict 33.54271 actual 35.7
# predict 21.309298 actual 21.0
# predict 28.12093 actual 30.0
# predict 34.85789 actual 31.8
# predict 27.471188 actual 30.0
# predict 14.795439 actual 15.0
# predict 36.15061 actual 39.0
# predict 32.815605 actual 36.0
# predict 28.880373 actual 31.0
# predict 14.764206 actual 14.0
# predict 29.788977 actual 29.8
# predict 20.135725 actual 19.0
# predict 18.494415 actual 16.0
# predict 14.741945 actual 17.5
# predict 14.54513 actual 13.0
# predict 26.443722 actual 28.0
# predict 14.14702 actual 14.0
# predict 14.738766 actual 14.0
# predict 27.447237 actual 27.9
# predict 22.541134 actual 20.8
# predict 22.691923 actual 20.5
# predict 27.20193 actual 22.3
# predict 22.436731 actual 24.0
# predict 29.339724 actual 27.0
# predict 9.38142 actual 10.0
# ...

# %%
print('training_data')
prediction_result_SSE_inverse(model_automobile, X_train_automobile, Y_train_automobile)
print('validation_data')
prediction_result_SSE_inverse(model_automobile, X_val_automobile, Y_val_automobile)
print('testing_data')
prediction_result_SSE_inverse(model_automobile, x_test_automobile, y_test_automobile)
# Out:
# training_data
# predict 17401.02 actual [12964.]
# predict 5984.042 actual [6918.]
# predict 7417.0107 actual [6529.]
# predict 9273.189 actual [9959.]
# predict 7419.671 actual [7129.]
# predict 14254.112 actual [9989.]
# predict 36343.52 actual [45400.]
# predict 10751.833 actual [10345.]
# predict 14487.87 actual [11900.]
# predict 30666.727 actual [32250.]
# predict 11482.066 actual [16925.]
# predict 12657.174 actual [13645.]
# predict 19806.361 actual [21485.]
# predict 3706.4194 actual [7957.]
# predict 9675.303 actual [8949.]
# predict 5929.3364 actual [7738.]
# predict 15601.584 actual [17450.]
# predict 8648.302 actual [7775.]
# predict 12652.984 actual [11845.]
# predict 26635.764 actual [13207.]
# predict 20521.57 actual [22470.]
# predict 10593.296 actual [9980.]
# predict 7838.713 actual [8058.]
# predict 7453.2764 actual [7295.]
# predict 14365.0 actual [11199.]
# predict 8627.978 actual [8948.]
# predict 15178.142 actual [15645.]
# predict 16156.828 actual [13200.]
# ...

# %%
print('training_data')
prediction_result_SSE(model_challenger, X_train_challenger, Y_train_challenger)
print('validation_data')
prediction_result_SSE(model_challenger, X_val_challenger, Y_val_challenger)
print('testing_data')
prediction_result_SSE(model_challenger, x_test_challenger, y_test_challenger)
# Out:
# training_data
# predict 5.999998 actual 6
# predict 5.9999995 actual 6
# predict 5.999999 actual 6
# predict 6.0000005 actual 6
# predict 6.0 actual 6
# predict 5.999998 actual 6
# predict 5.999999 actual 6
# predict 5.999999 actual 6
# predict 6.0 actual 6
# predict 6.0 actual 6
# predict 6.000001 actual 6
# predict 6.0 actual 6
# predict 6.000002 actual 6
# predict 6.000002 actual 6
# predict 5.9999986 actual 6
# predict 5.999999 actual 6
# predict 6.0 actual 6
# predict 6.0 actual 6
# predict 6.0 actual 6
# predict 6.0000005 actual 6
# predict 6.0 actual 6
# predict 6.0000005 actual 6
# predict 5.9999986 actual 6
# predict 5.9999995 actual 6
# predict 6.0000005 actual 6
# predict 5.999999 actual 6
# predict 6.0 actual 6
# predict 5.9999995 actual 6
# predict 5.9999986 actual 6
# predict 5.9999986 actual 6
# predict 6.0 actual 6
# predict 6.0000005 actual 6
# 1.5006662579253316e-11
# validation_data
# predict 6.0000005 actual 6
# predict 6.000001 actual 6
# ...

# %%
model_airfoil=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\PSO-MLP_model_airfoil_model_second_step_linear_seed2.h5')
training=model_airfoil.evaluate(X_train_airfoil, Y_train_airfoil, verbose=0)
validating=model_airfoil.evaluate(X_val_airfoil, Y_val_airfoil, verbose=0)
testing=model_airfoil.evaluate(x_test_airfoil, y_test_airfoil, verbose=0)
print(training)
print(validating)
print(testing)
# Out:
# 6.491522196127888
# 6.93758600725068
# 6.220887513287299

# %%
model_autompg=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FixedPSO-MLP_model_autompg_model_second_step_linear_seed2.h5')
training=model_autompg.evaluate(X_train_autompg, Y_train_autompg, verbose=0)
validating=model_autompg.evaluate(X_val_autompg, Y_val_autompg, verbose=0)
testing=model_autompg.evaluate(x_test_autompg, y_test_autompg, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 5.0175458358152065
# validation 7.0083260293734275
# testing 4.702643426798158

# %%
model_automobile=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FixedPSO-MLP_model_automobile_model_second_step_seed2.h5')
training=model_automobile.evaluate(X_train_automobile, Y_train_automobile, verbose=0)
validating=model_automobile.evaluate(X_val_automobile, Y_val_automobile, verbose=0)
testing=model_automobile.evaluate(x_test_automobile, y_test_automobile, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 0.002259460460212264
# validation 0.002251195488497615
# testing 0.007357347756624222

# %%
model_challenger=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\PSO-MLP_model_challenger_model_second_step_linear_seed2.h5')
training=model_challenger.evaluate(X_train_challenger, Y_train_challenger, verbose=0)
validating=model_challenger.evaluate(X_val_challenger, Y_val_challenger, verbose=0)
testing=model_challenger.evaluate(x_test_challenger, y_test_challenger, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 4.164565581277202e-08
# validation 4.874891601502895e-10
# testing 3.990797914354971e-09

# %%
print('training_data')
prediction_result_SSE(model_airfoil, X_train_airfoil, Y_train_airfoil)
print('validation_data')
prediction_result_SSE(model_airfoil, X_val_airfoil, Y_val_airfoil)
print('testing_data')
prediction_result_SSE(model_airfoil, x_test_airfoil, y_test_airfoil)
# Out:
# training_data
# predict 135.09822 actual 133.59799999999998
# predict 131.11642 actual 131.434
# predict 129.19243 actual 128.679
# predict 124.95348 actual 127.006
# predict 136.7655 actual 134.928
# predict 126.12633 actual 128.139
# predict 128.86626 actual 132.251
# predict 122.645004 actual 127.04
# predict 129.65192 actual 131.515
# predict 133.38542 actual 134.976
# predict 125.99217 actual 129.377
# predict 125.204124 actual 139.226
# predict 117.0508 actual 120.51299999999999
# predict 126.91619 actual 122.235
# predict 134.26361 actual 136.023
# predict 110.53272 actual 110.839
# predict 122.70149 actual 122.771
# predict 120.68299 actual 121.93299999999999
# predict 121.74734 actual 119.67
# predict 125.41714 actual 123.209
# predict 125.40508 actual 128.444
# predict 121.33733 actual 125.62700000000001
# predict 129.50987 actual 128.144
# predict 119.93696 actual 122.75399999999999
# predict 129.00401 actual 130.311
# predict 120.870865 actual 125.715
# ...

# %%
print('training_data')
prediction_result_SSE(model_autompg, X_train_autompg, Y_train_autompg)
print('validation_data')
prediction_result_SSE(model_autompg, X_val_autompg, Y_val_autompg)
print('testing_data')
prediction_result_SSE(model_autompg, x_test_autompg, y_test_autompg)
# Out:
# training_data
# predict 28.783817 actual 27.0
# predict 20.44787 actual 22.0
# predict 23.371065 actual 25.0
# predict 32.62785 actual 30.0
# predict 24.862942 actual 26.8
# predict 25.619892 actual 26.0
# predict 34.49277 actual 35.7
# predict 19.501255 actual 21.0
# predict 29.56105 actual 30.0
# predict 35.7498 actual 31.8
# predict 25.504446 actual 30.0
# predict 13.782319 actual 15.0
# predict 34.581253 actual 39.0
# predict 36.242672 actual 36.0
# predict 28.205381 actual 31.0
# predict 13.752287 actual 14.0
# predict 31.290693 actual 29.8
# predict 19.13504 actual 19.0
# predict 16.860315 actual 16.0
# predict 15.731375 actual 17.5
# predict 12.975842 actual 13.0
# predict 26.927134 actual 28.0
# predict 13.080421 actual 14.0
# predict 14.109498 actual 14.0
# predict 27.36325 actual 27.9
# predict 21.82794 actual 20.8
# predict 20.313124 actual 20.5
# predict 25.7286 actual 22.3
# predict 23.741615 actual 24.0
# predict 27.313059 actual 27.0
# predict 11.668393 actual 10.0
# ...

# %%
print('training_data')
prediction_result_SSE_inverse(model_automobile, X_train_automobile, Y_train_automobile)
print('validation_data')
prediction_result_SSE_inverse(model_automobile, X_val_automobile, Y_val_automobile)
print('testing_data')
prediction_result_SSE_inverse(model_automobile, x_test_automobile, y_test_automobile)
# Out:
# training_data
# predict 14042.377 actual [12964.]
# predict 8187.8433 actual [6918.]
# predict 7591.2554 actual [6529.]
# predict 9184.32 actual [9959.]
# predict 7573.5186 actual [7129.]
# predict 12347.966 actual [9989.]
# predict 46658.867 actual [45400.]
# predict 8794.469 actual [10345.]
# predict 15500.521 actual [11900.]
# predict 33816.477 actual [32250.]
# predict 15678.54 actual [16925.]
# predict 12595.72 actual [13645.]
# predict 24517.006 actual [21485.]
# predict 8830.643 actual [7957.]
# predict 9488.09 actual [8949.]
# predict 7270.0396 actual [7738.]
# predict 15567.154 actual [17450.]
# predict 9203.725 actual [7775.]
# predict 12580.52 actual [11845.]
# predict 15255.433 actual [13207.]
# predict 21264.535 actual [22470.]
# predict 11071.35 actual [9980.]
# predict 8039.8853 actual [8058.]
# predict 8136.579 actual [7295.]
# predict 12641.966 actual [11199.]
# predict 10175.367 actual [8948.]
# predict 16554.02 actual [15645.]
# predict 15211.915 actual [13200.]
# ...

# %%
print('training_data')
prediction_result_SSE(model_challenger, X_train_challenger, Y_train_challenger)
print('validation_data')
prediction_result_SSE(model_challenger, X_val_challenger, Y_val_challenger)
print('testing_data')
prediction_result_SSE(model_challenger, x_test_challenger, y_test_challenger)
# Out:
# training_data
# predict 5.9998627 actual 6
# predict 5.9999604 actual 6
# predict 5.999935 actual 6
# predict 5.99983 actual 6
# predict 5.999983 actual 6
# predict 5.9998627 actual 6
# predict 6.00003 actual 6
# predict 6.0003977 actual 6
# predict 5.999589 actual 6
# predict 5.9999714 actual 6
# predict 6.000011 actual 6
# predict 6.000137 actual 6
# predict 6.000544 actual 6
# predict 6.000544 actual 6
# predict 5.999786 actual 6
# predict 6.0003977 actual 6
# predict 6.0001235 actual 6
# predict 6.000029 actual 6
# predict 6.0001235 actual 6
# predict 5.9999995 actual 6
# predict 5.9999743 actual 6
# predict 5.99983 actual 6
# predict 6.000046 actual 6
# predict 5.9999604 actual 6
# predict 5.9999824 actual 6
# predict 5.9999676 actual 6
# predict 5.9999743 actual 6
# predict 5.9999685 actual 6
# predict 6.000046 actual 6
# predict 5.999786 actual 6
# predict 5.999983 actual 6
# predict 5.9999824 actual 6
# 6.663304930043523e-07
# validation_data
# predict 5.9999824 actual 6
# ...

# %%
model_airfoil=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\PSO-MLP_model_airfoil_model_second_step_linear_seed3.h5')
training=model_airfoil.evaluate(X_train_airfoil, Y_train_airfoil, verbose=0)
validating=model_airfoil.evaluate(X_val_airfoil, Y_val_airfoil, verbose=0)
testing=model_airfoil.evaluate(x_test_airfoil, y_test_airfoil, verbose=0)
print(training)
print(validating)
print(testing)
# Out:
# 6.51589701656153
# 6.687830327351888
# 6.338902912308685

# %%
model_autompg=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FixedPSO-MLP_model_autompg_model_second_step_linear_seed3.h5')
training=model_autompg.evaluate(X_train_autompg, Y_train_autompg, verbose=0)
validating=model_autompg.evaluate(X_val_autompg, Y_val_autompg, verbose=0)
testing=model_autompg.evaluate(x_test_autompg, y_test_autompg, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 5.185017839835508
# validation 6.0862868115053335
# testing 4.2329929440708485

# %%
model_automobile=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FixedPSO-MLP_model_automobile_model_second_step_seed3.h5')
training=model_automobile.evaluate(X_train_automobile, Y_train_automobile, verbose=0)
validating=model_automobile.evaluate(X_val_automobile, Y_val_automobile, verbose=0)
testing=model_automobile.evaluate(x_test_automobile, y_test_automobile, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 0.0017460494504108295
# validation 0.002999593736603856
# testing 0.005391438491642475

# %%
model_challenger=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\PSO-MLP_model_challenger_model_second_step_linear_seed3.h5')
training=model_challenger.evaluate(X_train_challenger, Y_train_challenger, verbose=0)
validating=model_challenger.evaluate(X_val_challenger, Y_val_challenger, verbose=0)
testing=model_challenger.evaluate(x_test_challenger, y_test_challenger, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 1.9895196601282805e-12
# validation 2.598556352734205e-12
# testing 1.9489171561304364e-12

# %%
print('training_data')
prediction_result_SSE(model_airfoil, X_train_airfoil, Y_train_airfoil)
print('validation_data')
prediction_result_SSE(model_airfoil, X_val_airfoil, Y_val_airfoil)
print('testing_data')
prediction_result_SSE(model_airfoil, x_test_airfoil, y_test_airfoil)
# Out:
# training_data
# predict 135.11708 actual 133.59799999999998
# predict 131.31226 actual 131.434
# predict 129.32944 actual 128.679
# predict 124.87506 actual 127.006
# predict 137.0379 actual 134.928
# predict 125.90255 actual 128.139
# predict 128.86589 actual 132.251
# predict 122.90265 actual 127.04
# predict 130.74844 actual 131.515
# predict 133.97018 actual 134.976
# predict 125.9843 actual 129.377
# predict 126.07648 actual 139.226
# predict 117.89968 actual 120.51299999999999
# predict 126.685555 actual 122.235
# predict 134.38187 actual 136.023
# predict 110.87408 actual 110.839
# predict 122.486206 actual 122.771
# predict 121.30022 actual 121.93299999999999
# predict 122.2921 actual 119.67
# predict 125.72996 actual 123.209
# predict 126.313225 actual 128.444
# predict 121.87533 actual 125.62700000000001
# predict 129.50015 actual 128.144
# predict 120.1867 actual 122.75399999999999
# predict 129.57184 actual 130.311
# predict 121.574646 actual 125.715
# ...

# %%
print('training_data')
prediction_result_SSE(model_autompg, X_train_autompg, Y_train_autompg)
print('validation_data')
prediction_result_SSE(model_autompg, X_val_autompg, Y_val_autompg)
print('testing_data')
prediction_result_SSE(model_autompg, x_test_autompg, y_test_autompg)
# Out:
# training_data
# predict 27.723808 actual 27.0
# predict 20.780893 actual 22.0
# predict 23.884653 actual 25.0
# predict 31.354895 actual 30.0
# predict 24.21528 actual 26.8
# predict 24.516174 actual 26.0
# predict 32.588142 actual 35.7
# predict 20.871449 actual 21.0
# predict 29.8376 actual 30.0
# predict 35.242577 actual 31.8
# predict 25.758806 actual 30.0
# predict 14.638852 actual 15.0
# predict 38.213448 actual 39.0
# predict 35.818047 actual 36.0
# predict 28.900383 actual 31.0
# predict 13.936259 actual 14.0
# predict 31.015154 actual 29.8
# predict 19.464441 actual 19.0
# predict 16.595268 actual 16.0
# predict 15.761169 actual 17.5
# predict 13.218033 actual 13.0
# predict 28.337114 actual 28.0
# predict 14.222724 actual 14.0
# predict 14.15331 actual 14.0
# predict 24.690363 actual 27.9
# predict 23.146791 actual 20.8
# predict 21.292166 actual 20.5
# predict 24.189642 actual 22.3
# predict 23.185905 actual 24.0
# predict 27.882805 actual 27.0
# ...

# %%
print('training_data')
prediction_result_SSE_inverse(model_automobile, X_train_automobile, Y_train_automobile)
print('validation_data')
prediction_result_SSE_inverse(model_automobile, X_val_automobile, Y_val_automobile)
print('testing_data')
prediction_result_SSE_inverse(model_automobile, x_test_automobile, y_test_automobile)
# Out:
# training_data
# predict 13715.602 actual [12964.]
# predict 8796.186 actual [6918.]
# predict 7523.2803 actual [6529.]
# predict 9374.925 actual [9959.]
# predict 7548.87 actual [7129.]
# predict 12515.387 actual [9989.]
# predict 44815.29 actual [45400.]
# predict 8875.863 actual [10345.]
# predict 15734.1455 actual [11900.]
# predict 30911.129 actual [32250.]
# predict 14483.998 actual [16925.]
# predict 12833.096 actual [13645.]
# predict 23526.219 actual [21485.]
# predict 7541.1016 actual [7957.]
# predict 9420.326 actual [8949.]
# predict 9296.781 actual [7738.]
# predict 15005.372 actual [17450.]
# predict 7283.123 actual [7775.]
# predict 12830.954 actual [11845.]
# predict 13255.873 actual [13207.]
# predict 19543.348 actual [22470.]
# predict 9800.008 actual [9980.]
# predict 8470.022 actual [8058.]
# predict 8792.632 actual [7295.]
# predict 12939.587 actual [11199.]
# predict 9533.523 actual [8948.]
# predict 15297.018 actual [15645.]
# predict 16255.523 actual [13200.]
# ...

# %%
print('training_data')
prediction_result_SSE(model_challenger, X_train_challenger, Y_train_challenger)
print('validation_data')
prediction_result_SSE(model_challenger, X_val_challenger, Y_val_challenger)
print('testing_data')
prediction_result_SSE(model_challenger, x_test_challenger, y_test_challenger)
# Out:
# training_data
# predict 6.000002 actual 6
# predict 5.999999 actual 6
# predict 6.000001 actual 6
# predict 5.999999 actual 6
# predict 5.999999 actual 6
# predict 6.000002 actual 6
# predict 5.999999 actual 6
# predict 6.000001 actual 6
# predict 5.999999 actual 6
# predict 5.999999 actual 6
# predict 5.999999 actual 6
# predict 5.999997 actual 6
# predict 6.000002 actual 6
# predict 6.000002 actual 6
# predict 6.000001 actual 6
# predict 6.000001 actual 6
# predict 5.999999 actual 6
# predict 6.000001 actual 6
# predict 5.999999 actual 6
# predict 6.0 actual 6
# predict 5.999999 actual 6
# predict 5.999999 actual 6
# predict 6.000002 actual 6
# predict 5.999999 actual 6
# predict 6.0 actual 6
# predict 6.000004 actual 6
# predict 5.999999 actual 6
# predict 5.999999 actual 6
# predict 6.000002 actual 6
# predict 6.000001 actual 6
# predict 5.999999 actual 6
# predict 6.0 actual 6
# 3.183231456205249e-11
# validation_data
# predict 6.0 actual 6
# predict 5.999999 actual 6
# ...

# %% [markdown]
# # Improved PSO-MLP

# %%
model_airfoil=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\ImprovedPSO-MLP_model_airfoil_model_second_step_linear.h5')
training=model_airfoil.evaluate(X_train_airfoil, Y_train_airfoil, verbose=0)
validating=model_airfoil.evaluate(X_val_airfoil, Y_val_airfoil, verbose=0)
testing=model_airfoil.evaluate(x_test_airfoil, y_test_airfoil, verbose=0)
print(training)
print(validating)
print(testing)
# Out:
# 6.561701547963538
# 8.082899707572327
# 6.001728699270603

# %%
model_autompg=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\PSO-MLP_model_autompg_model_second_step_linear.h5')
training=model_autompg.evaluate(X_train_autompg, Y_train_autompg, verbose=0)
validating=model_autompg.evaluate(X_val_autompg, Y_val_autompg, verbose=0)
testing=model_autompg.evaluate(x_test_autompg, y_test_autompg, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 6.211232248013907
# validation 7.31915730136936
# testing 4.332627155013004

# %%
model_automobile=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\PSO-MLP_model_automobile_model_second_step.h5')
training=model_automobile.evaluate(X_train_automobile, Y_train_automobile, verbose=0)
validating=model_automobile.evaluate(X_val_automobile, Y_val_automobile, verbose=0)
testing=model_automobile.evaluate(x_test_automobile, y_test_automobile, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 0.0015402561382527327
# validation 0.00200781156308949
# testing 0.005122174043208361

# %%
model_challenger=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\ImprovedPSO-MLP_model_challenger_model_second_step_linear.h5')
training=model_challenger.evaluate(X_train_challenger, Y_train_challenger, verbose=0)
validating=model_challenger.evaluate(X_val_challenger, Y_val_challenger, verbose=0)
testing=model_challenger.evaluate(x_test_challenger, y_test_challenger, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 3.218758592993254e-12
# validation 2.5011104298755527e-12
# testing 6.821210263296962e-13

# %%
print('training_data')
prediction_result_SSE(model_airfoil, X_train_airfoil, Y_train_airfoil)
print('validation_data')
prediction_result_SSE(model_airfoil, X_val_airfoil, Y_val_airfoil)
print('testing_data')
prediction_result_SSE(model_airfoil, x_test_airfoil, y_test_airfoil)
# Out:
# training_data
# predict 132.29338 actual 133.59799999999998
# predict 131.12405 actual 131.434
# predict 130.186 actual 128.679
# predict 127.51399 actual 127.006
# predict 135.4481 actual 134.928
# predict 127.00346 actual 128.139
# predict 129.11844 actual 132.251
# predict 121.16609 actual 127.04
# predict 129.75769 actual 131.515
# predict 135.99326 actual 134.976
# predict 129.50018 actual 129.377
# predict 126.93512 actual 139.226
# predict 116.61593 actual 120.51299999999999
# predict 126.00151 actual 122.235
# predict 135.65332 actual 136.023
# predict 109.92562 actual 110.839
# predict 123.10985 actual 122.771
# predict 121.34719 actual 121.93299999999999
# predict 121.37311 actual 119.67
# predict 126.495384 actual 123.209
# predict 124.49648 actual 128.444
# predict 122.373856 actual 125.62700000000001
# predict 130.67006 actual 128.144
# predict 120.49654 actual 122.75399999999999
# predict 130.34879 actual 130.311
# predict 119.540436 actual 125.715
# ...

# %%
print('training_data')
prediction_result_SSE(model_autompg, X_train_autompg, Y_train_autompg)
print('validation_data')
prediction_result_SSE(model_autompg, X_val_autompg, Y_val_autompg)
print('testing_data')
prediction_result_SSE(model_autompg, x_test_autompg, y_test_autompg)
# Out:
# training_data
# predict 26.824621 actual 27.0
# predict 18.713148 actual 22.0
# predict 22.8334 actual 25.0
# predict 30.87169 actual 30.0
# predict 22.478449 actual 26.8
# predict 23.889734 actual 26.0
# predict 33.522842 actual 35.7
# predict 20.468746 actual 21.0
# predict 29.164112 actual 30.0
# predict 36.20911 actual 31.8
# predict 23.827675 actual 30.0
# predict 13.417951 actual 15.0
# predict 36.91618 actual 39.0
# predict 34.125164 actual 36.0
# predict 29.940256 actual 31.0
# predict 13.139999 actual 14.0
# predict 29.918108 actual 29.8
# predict 19.56555 actual 19.0
# predict 17.047937 actual 16.0
# predict 14.745074 actual 17.5
# predict 12.7029085 actual 13.0
# predict 25.260828 actual 28.0
# predict 12.218361 actual 14.0
# predict 13.566044 actual 14.0
# predict 26.711943 actual 27.9
# predict 22.833853 actual 20.8
# predict 22.00751 actual 20.5
# predict 26.25273 actual 22.3
# predict 21.877407 actual 24.0
# predict 27.961071 actual 27.0
# ...

# %%
print('training_data')
prediction_result_SSE_inverse(model_automobile, X_train_automobile, Y_train_automobile)
print('validation_data')
prediction_result_SSE_inverse(model_automobile, X_val_automobile, Y_val_automobile)
print('testing_data')
prediction_result_SSE_inverse(model_automobile, x_test_automobile, y_test_automobile)
# Out:
# training_data
# predict 12845.532 actual [12964.]
# predict 7446.662 actual [6918.]
# predict 7279.2524 actual [6529.]
# predict 11522.283 actual [9959.]
# predict 7297.242 actual [7129.]
# predict 12352.1875 actual [9989.]
# predict 45613.42 actual [45400.]
# predict 7954.7983 actual [10345.]
# predict 15769.059 actual [11900.]
# predict 33253.484 actual [32250.]
# predict 14597.242 actual [16925.]
# predict 12276.847 actual [13645.]
# predict 25617.94 actual [21485.]
# predict 8490.919 actual [7957.]
# predict 9650.658 actual [8949.]
# predict 9036.612 actual [7738.]
# predict 15574.234 actual [17450.]
# predict 7897.807 actual [7775.]
# predict 12263.361 actual [11845.]
# predict 14692.156 actual [13207.]
# predict 22620.44 actual [22470.]
# predict 10686.561 actual [9980.]
# predict 7653.8345 actual [8058.]
# predict 8808.839 actual [7295.]
# predict 12630.487 actual [11199.]
# predict 9343.452 actual [8948.]
# predict 14977.565 actual [15645.]
# ...

# %%
print('training_data')
prediction_result_SSE(model_challenger, X_train_challenger, Y_train_challenger)
print('validation_data')
prediction_result_SSE(model_challenger, X_val_challenger, Y_val_challenger)
print('testing_data')
prediction_result_SSE(model_challenger, x_test_challenger, y_test_challenger)
# Out:
# training_data
# predict 5.999999 actual 6
# predict 6.0 actual 6
# predict 6.0 actual 6
# predict 5.9999986 actual 6
# predict 5.9999957 actual 6
# predict 5.999999 actual 6
# predict 6.000001 actual 6
# predict 6.0000014 actual 6
# predict 5.9999967 actual 6
# predict 5.999998 actual 6
# predict 6.000001 actual 6
# predict 6.0000014 actual 6
# predict 5.9999986 actual 6
# predict 5.9999986 actual 6
# predict 6.000001 actual 6
# predict 6.0000014 actual 6
# predict 6.000001 actual 6
# predict 5.999999 actual 6
# predict 6.000001 actual 6
# predict 5.9999995 actual 6
# predict 5.9999995 actual 6
# predict 5.9999986 actual 6
# predict 6.000003 actual 6
# predict 6.0 actual 6
# predict 6.0 actual 6
# predict 5.999998 actual 6
# predict 5.9999995 actual 6
# predict 6.000003 actual 6
# predict 6.000003 actual 6
# predict 6.000001 actual 6
# predict 5.9999957 actual 6
# predict 6.0 actual 6
# 5.150013748789206e-11
# validation_data
# predict 6.0 actual 6
# predict 6.000001 actual 6
# ...

# %%
model_airfoil=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\ImprovedPSO-MLP_model_airfoil_model_second_step_linear_seed2.h5')
training=model_airfoil.evaluate(X_train_airfoil, Y_train_airfoil, verbose=0)
validating=model_airfoil.evaluate(X_val_airfoil, Y_val_airfoil, verbose=0)
testing=model_airfoil.evaluate(x_test_airfoil, y_test_airfoil, verbose=0)
print(training)
print(validating)
print(testing)
# Out:
# 6.450942492757007
# 6.926404822634326
# 6.300358291220876

# %%
model_autompg=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\PSO-MLP_model_autompg_model_second_step_linear_seed2.h5')
training=model_autompg.evaluate(X_train_autompg, Y_train_autompg, verbose=0)
validating=model_autompg.evaluate(X_val_autompg, Y_val_autompg, verbose=0)
testing=model_autompg.evaluate(x_test_autompg, y_test_autompg, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 5.38328389355736
# validation 7.8142173492302325
# testing 4.801482572393902

# %%
model_automobile=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\PSO-MLP_model_automobile_model_second_step_seed2.h5')
training=model_automobile.evaluate(X_train_automobile, Y_train_automobile, verbose=0)
validating=model_automobile.evaluate(X_val_automobile, Y_val_automobile, verbose=0)
testing=model_automobile.evaluate(x_test_automobile, y_test_automobile, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)  #UNFINISHED
# Out:
# WARNING:tensorflow:From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# training 0.0013049797910441468
# validation 0.002576911123469472
# testing 0.0053235264495015144

# %%
model_challenger=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\ImprovedPSO-MLP_model_challenger_model_second_step_linear_seed2.h5')
training=model_challenger.evaluate(X_train_challenger, Y_train_challenger, verbose=0)
validating=model_challenger.evaluate(X_val_challenger, Y_val_challenger, verbose=0)
testing=model_challenger.evaluate(x_test_challenger, y_test_challenger, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 9.522636901238002e-09
# validation 5.599888885932103e-10
# testing 6.614624958878323e-10

# %%
print('training_data')
prediction_result_SSE(model_airfoil, X_train_airfoil, Y_train_airfoil)
print('validation_data')
prediction_result_SSE(model_airfoil, X_val_airfoil, Y_val_airfoil)
print('testing_data')
prediction_result_SSE(model_airfoil, x_test_airfoil, y_test_airfoil)
# Out:
# training_data
# predict 134.82372 actual 133.59799999999998
# predict 131.33139 actual 131.434
# predict 129.88126 actual 128.679
# predict 124.873215 actual 127.006
# predict 136.12688 actual 134.928
# predict 126.300415 actual 128.139
# predict 129.34833 actual 132.251
# predict 122.84922 actual 127.04
# predict 130.22014 actual 131.515
# predict 133.45575 actual 134.976
# predict 126.09685 actual 129.377
# predict 125.52193 actual 139.226
# predict 116.97578 actual 120.51299999999999
# predict 127.244736 actual 122.235
# predict 134.25444 actual 136.023
# predict 110.543274 actual 110.839
# predict 123.04109 actual 122.771
# predict 119.57647 actual 121.93299999999999
# predict 121.79402 actual 119.67
# predict 125.97147 actual 123.209
# predict 125.93191 actual 128.444
# predict 120.52291 actual 125.62700000000001
# predict 129.3448 actual 128.144
# predict 120.56773 actual 122.75399999999999
# predict 129.68095 actual 130.311
# predict 120.87563 actual 125.715
# ...

# %%
print('training_data')
prediction_result_SSE(model_autompg, X_train_autompg, Y_train_autompg)
print('validation_data')
prediction_result_SSE(model_autompg, X_val_autompg, Y_val_autompg)
print('testing_data')
prediction_result_SSE(model_autompg, x_test_autompg, y_test_autompg)
# Out:
# training_data
# predict 25.965435 actual 27.0
# predict 20.857561 actual 22.0
# predict 24.75062 actual 25.0
# predict 30.55518 actual 30.0
# predict 24.773302 actual 26.8
# predict 22.820433 actual 26.0
# predict 32.732487 actual 35.7
# predict 20.609388 actual 21.0
# predict 29.231564 actual 30.0
# predict 34.97217 actual 31.8
# predict 26.396532 actual 30.0
# predict 13.528004 actual 15.0
# predict 39.5374 actual 39.0
# predict 35.776676 actual 36.0
# predict 27.65933 actual 31.0
# predict 13.262415 actual 14.0
# predict 29.832787 actual 29.8
# predict 19.387426 actual 19.0
# predict 15.535653 actual 16.0
# predict 16.08664 actual 17.5
# predict 13.557436 actual 13.0
# predict 26.415821 actual 28.0
# predict 13.172042 actual 14.0
# predict 13.313361 actual 14.0
# predict 25.435116 actual 27.9
# predict 22.965403 actual 20.8
# predict 20.835114 actual 20.5
# predict 25.113363 actual 22.3
# predict 21.011988 actual 24.0
# predict 27.024511 actual 27.0
# predict 13.27081 actual 10.0
# ...

# %%
print('training_data')
prediction_result_SSE_inverse(model_automobile, X_train_automobile, Y_train_automobile)
print('validation_data')
prediction_result_SSE_inverse(model_automobile, X_val_automobile, Y_val_automobile)
print('testing_data')
prediction_result_SSE_inverse(model_automobile, x_test_automobile, y_test_automobile)
# Out:
# training_data
# predict 14586.386 actual [12964.]
# predict 7471.5737 actual [6918.]
# predict 6998.8813 actual [6529.]
# predict 9377.633 actual [9959.]
# predict 7028.1255 actual [7129.]
# predict 11553.404 actual [9989.]
# predict 44160.5 actual [45400.]
# predict 7223.283 actual [10345.]
# predict 13711.46 actual [11900.]
# predict 31683.562 actual [32250.]
# predict 13775.282 actual [16925.]
# predict 11308.585 actual [13645.]
# predict 22209.68 actual [21485.]
# predict 7759.4194 actual [7957.]
# predict 8531.925 actual [8949.]
# predict 8729.771 actual [7738.]
# predict 16708.777 actual [17450.]
# predict 6760.1 actual [7775.]
# predict 11289.6875 actual [11845.]
# predict 13459.91 actual [13207.]
# predict 20490.3 actual [22470.]
# predict 9565.768 actual [9980.]
# predict 6657.9355 actual [8058.]
# predict 8328.423 actual [7295.]
# predict 11979.588 actual [11199.]
# predict 9551.374 actual [8948.]
# predict 15852.8545 actual [15645.]
# predict 14592.252 actual [13200.]
# ...

# %%
print('training_data')
prediction_result_SSE(model_challenger, X_train_challenger, Y_train_challenger)
print('validation_data')
prediction_result_SSE(model_challenger, X_val_challenger, Y_val_challenger)
print('testing_data')
prediction_result_SSE(model_challenger, x_test_challenger, y_test_challenger)
# Out:
# training_data
# predict 6.0000257 actual 6
# predict 5.999959 actual 6
# predict 6.000019 actual 6
# predict 6.0001106 actual 6
# predict 5.999916 actual 6
# predict 6.0000257 actual 6
# predict 5.9999733 actual 6
# predict 5.999938 actual 6
# predict 6.000332 actual 6
# predict 6.0 actual 6
# predict 6.0000086 actual 6
# predict 5.9999924 actual 6
# predict 6.0001564 actual 6
# predict 6.0001564 actual 6
# predict 5.999959 actual 6
# predict 5.999938 actual 6
# predict 6.0001907 actual 6
# predict 6.0000076 actual 6
# predict 6.0001907 actual 6
# predict 5.999984 actual 6
# predict 6.0000744 actual 6
# predict 6.0001106 actual 6
# predict 6.0000124 actual 6
# predict 5.999959 actual 6
# predict 5.9999533 actual 6
# predict 6.0000257 actual 6
# predict 6.0000744 actual 6
# predict 5.9999743 actual 6
# predict 6.0000124 actual 6
# predict 5.999959 actual 6
# predict 5.999916 actual 6
# predict 5.9999533 actual 6
# 1.5236219041980803e-07
# validation_data
# predict 5.9999533 actual 6
# ...

# %%
model_airfoil=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\ImprovedPSO-MLP_model_airfoil_model_second_step_linear_seed3.h5')
training=model_airfoil.evaluate(X_train_airfoil, Y_train_airfoil, verbose=0)
validating=model_airfoil.evaluate(X_val_airfoil, Y_val_airfoil, verbose=0)
testing=model_airfoil.evaluate(x_test_airfoil, y_test_airfoil, verbose=0)
print(training)
print(validating)
print(testing)
# Out:
# 6.560371213992739
# 6.858825488752789
# 6.355426627977759

# %%
model_autompg=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\PSO-MLP_model_autompg_model_second_step_linear_seed3.h5')
training=model_autompg.evaluate(X_train_autompg, Y_train_autompg, verbose=0)
validating=model_autompg.evaluate(X_val_autompg, Y_val_autompg, verbose=0)
testing=model_autompg.evaluate(x_test_autompg, y_test_autompg, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 5.7468590527555365
# validation 6.526108458890754
# testing 4.720102071762085

# %%
model_automobile=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\PSO-MLP_model_automobile_model_second_step_seed3.h5')
training=model_automobile.evaluate(X_train_automobile, Y_train_automobile, verbose=0)
validating=model_automobile.evaluate(X_val_automobile, Y_val_automobile, verbose=0)
testing=model_automobile.evaluate(x_test_automobile, y_test_automobile, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 0.001990481751964434
# validation 0.0035038371570408344
# testing 0.003870827378705144

# %%
model_challenger=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\ImprovedPSO-MLP_model_challenger_model_second_step_linear_seed3.h5')
training=model_challenger.evaluate(X_train_challenger, Y_train_challenger, verbose=0)
validating=model_challenger.evaluate(X_val_challenger, Y_val_challenger, verbose=0)
testing=model_challenger.evaluate(x_test_challenger, y_test_challenger, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 7.898393050709274e-11
# validation 6.678289865558185e-11
# testing 6.4963906649950776e-12

# %%
print('training_data')
prediction_result_SSE(model_airfoil, X_train_airfoil, Y_train_airfoil)
print('validation_data')
prediction_result_SSE(model_airfoil, X_val_airfoil, Y_val_airfoil)
print('testing_data')
prediction_result_SSE(model_airfoil, x_test_airfoil, y_test_airfoil)
# Out:
# training_data
# predict 134.95326 actual 133.59799999999998
# predict 131.23386 actual 131.434
# predict 129.84357 actual 128.679
# predict 124.67975 actual 127.006
# predict 136.16742 actual 134.928
# predict 125.89969 actual 128.139
# predict 129.30643 actual 132.251
# predict 123.18207 actual 127.04
# predict 130.73985 actual 131.515
# predict 133.72379 actual 134.976
# predict 125.937225 actual 129.377
# predict 125.813644 actual 139.226
# predict 117.8197 actual 120.51299999999999
# predict 126.97632 actual 122.235
# predict 134.14732 actual 136.023
# predict 110.80368 actual 110.839
# predict 122.63428 actual 122.771
# predict 120.52403 actual 121.93299999999999
# predict 122.29782 actual 119.67
# predict 125.93092 actual 123.209
# predict 126.33685 actual 128.444
# predict 121.267715 actual 125.62700000000001
# predict 129.13249 actual 128.144
# predict 120.38547 actual 122.75399999999999
# predict 130.01707 actual 130.311
# predict 121.65744 actual 125.715
# ...

# %%
print('training_data')
prediction_result_SSE(model_autompg, X_train_autompg, Y_train_autompg)
print('validation_data')
prediction_result_SSE(model_autompg, X_val_autompg, Y_val_autompg)
print('testing_data')
prediction_result_SSE(model_autompg, x_test_autompg, y_test_autompg)
# Out:
# training_data
# predict 27.441618 actual 27.0
# predict 18.385098 actual 22.0
# predict 23.57485 actual 25.0
# predict 31.491718 actual 30.0
# predict 24.746065 actual 26.8
# predict 25.276342 actual 26.0
# predict 35.567417 actual 35.7
# predict 19.615084 actual 21.0
# predict 29.75984 actual 30.0
# predict 35.56284 actual 31.8
# predict 26.373125 actual 30.0
# predict 13.365947 actual 15.0
# predict 35.645435 actual 39.0
# predict 33.3742 actual 36.0
# predict 27.773722 actual 31.0
# predict 13.350913 actual 14.0
# predict 28.689129 actual 29.8
# predict 17.862963 actual 19.0
# predict 17.287046 actual 16.0
# predict 13.981183 actual 17.5
# predict 13.342406 actual 13.0
# predict 27.889761 actual 28.0
# predict 13.357004 actual 14.0
# predict 13.360142 actual 14.0
# predict 28.273678 actual 27.9
# predict 21.76165 actual 20.8
# predict 19.171883 actual 20.5
# predict 25.170567 actual 22.3
# predict 22.795654 actual 24.0
# predict 27.166471 actual 27.0
# ...

# %%
print('training_data')
prediction_result_SSE_inverse(model_automobile, X_train_automobile, Y_train_automobile)
print('validation_data')
prediction_result_SSE_inverse(model_automobile, X_val_automobile, Y_val_automobile)
print('testing_data')
prediction_result_SSE_inverse(model_automobile, x_test_automobile, y_test_automobile)
# Out:
# training_data
# predict 13900.406 actual [12964.]
# predict 7737.4937 actual [6918.]
# predict 6986.6055 actual [6529.]
# predict 11112.264 actual [9959.]
# predict 6987.307 actual [7129.]
# predict 12324.517 actual [9989.]
# predict 46553.26 actual [45400.]
# predict 7041.335 actual [10345.]
# predict 14877.701 actual [11900.]
# predict 32801.64 actual [32250.]
# predict 12411.983 actual [16925.]
# predict 13256.237 actual [13645.]
# predict 22662.049 actual [21485.]
# predict 8136.2314 actual [7957.]
# predict 9035.072 actual [8949.]
# predict 8059.325 actual [7738.]
# predict 18501.803 actual [17450.]
# predict 7836.5938 actual [7775.]
# predict 13255.235 actual [11845.]
# predict 14884.774 actual [13207.]
# predict 20897.162 actual [22470.]
# predict 10682.483 actual [9980.]
# predict 7250.775 actual [8058.]
# predict 8126.063 actual [7295.]
# predict 12701.336 actual [11199.]
# predict 9626.641 actual [8948.]
# predict 14026.02 actual [15645.]
# ...

# %%
print('training_data')
prediction_result_SSE(model_challenger, X_train_challenger, Y_train_challenger)
print('validation_data')
prediction_result_SSE(model_challenger, X_val_challenger, Y_val_challenger)
print('testing_data')
prediction_result_SSE(model_challenger, x_test_challenger, y_test_challenger)
# Out:
# training_data
# predict 5.999997 actual 6
# predict 6.000004 actual 6
# predict 6.000001 actual 6
# predict 5.999997 actual 6
# predict 5.999977 actual 6
# predict 5.999997 actual 6
# predict 5.999997 actual 6
# predict 5.9999933 actual 6
# predict 5.999983 actual 6
# predict 5.999981 actual 6
# predict 5.999998 actual 6
# predict 6.000002 actual 6
# predict 5.999998 actual 6
# predict 5.999998 actual 6
# predict 5.9999924 actual 6
# predict 5.9999933 actual 6
# predict 6.0000143 actual 6
# predict 6.0 actual 6
# predict 6.0000143 actual 6
# predict 6.0000057 actual 6
# predict 6.0 actual 6
# predict 5.999997 actual 6
# predict 6.000001 actual 6
# predict 6.000004 actual 6
# predict 6.000005 actual 6
# predict 6.0000057 actual 6
# predict 6.0 actual 6
# predict 6.000003 actual 6
# predict 6.000001 actual 6
# predict 5.9999924 actual 6
# predict 5.999977 actual 6
# predict 6.000005 actual 6
# 1.2637428881134838e-09
# validation_data
# predict 6.000005 actual 6
# ...

# %% [markdown]
# # FA-MLP

# %%
model_airfoil.load_weights('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FA-MLP_model_airfoil_second_step.h5')
training=model_airfoil.evaluate(X_train_airfoil, Y_train_airfoil, verbose=0)
validating=model_airfoil.evaluate(X_val_airfoil, Y_val_airfoil, verbose=0)
testing=model_airfoil.evaluate(x_test_airfoil, y_test_airfoil, verbose=0)
print(training)
print(validating)
print(testing)
# Out:
# 6.59316605669464
# 7.17072893248664
# 6.2404051417798065

# %%
model_autompg=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FA-MLP_model_autompg_second_step.h5')
training=model_autompg.evaluate(X_train_autompg, Y_train_autompg, verbose=0)
validating=model_autompg.evaluate(X_val_autompg, Y_val_autompg, verbose=0)
testing=model_autompg.evaluate(x_test_autompg, y_test_autompg, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 6.512101719849301
# validation 7.8298313900575796
# testing 5.520779278318761

# %%
model_automobile=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FA-MLP_model_automobile_second_step.h5')
training=model_automobile.evaluate(X_train_automobile, Y_train_automobile, verbose=0)
validating=model_automobile.evaluate(X_val_automobile, Y_val_automobile, verbose=0)
testing=model_automobile.evaluate(x_test_automobile, y_test_automobile, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 0.004237768416117121
# validation 0.002163428347557783
# testing 0.007778380997478962

# %%
model_challenger=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FA-MLP_model_challenger_second_step.h5')
training=model_challenger.evaluate(X_train_challenger, Y_train_challenger, verbose=0)
validating=model_challenger.evaluate(X_val_challenger, Y_val_challenger, verbose=0)
testing=model_challenger.evaluate(x_test_challenger, y_test_challenger, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 1.4664092873317713e-07
# validation 6.981973399433627e-08
# testing 9.399367506546241e-09

# %%
print('training_data')
prediction_result_SSE(model_airfoil, X_train_airfoil, Y_train_airfoil)
print('validation_data')
prediction_result_SSE(model_airfoil, X_val_airfoil, Y_val_airfoil)
print('testing_data')
prediction_result_SSE(model_airfoil, x_test_airfoil, y_test_airfoil)
# Out:
# training_data
# predict 135.12944 actual 133.59799999999998
# predict 131.8478 actual 131.434
# predict 129.25404 actual 128.679
# predict 124.70892 actual 127.006
# predict 136.7064 actual 134.928
# predict 125.69511 actual 128.139
# predict 128.82964 actual 132.251
# predict 122.286896 actual 127.04
# predict 130.97375 actual 131.515
# predict 133.57796 actual 134.976
# predict 126.05293 actual 129.377
# predict 124.72518 actual 139.226
# predict 116.59728 actual 120.51299999999999
# predict 126.297104 actual 122.235
# predict 134.64497 actual 136.023
# predict 110.15946 actual 110.839
# predict 122.06321 actual 122.771
# predict 119.58338 actual 121.93299999999999
# predict 121.274376 actual 119.67
# predict 125.611084 actual 123.209
# predict 125.56438 actual 128.444
# predict 120.060715 actual 125.62700000000001
# predict 129.43619 actual 128.144
# predict 120.77339 actual 122.75399999999999
# predict 129.71309 actual 130.311
# predict 120.94729 actual 125.715
# ...

# %%
print('training_data')
prediction_result_SSE(model_autompg, X_train_autompg, Y_train_autompg)
print('validation_data')
prediction_result_SSE(model_autompg, X_val_autompg, Y_val_autompg)
print('testing_data')
prediction_result_SSE(model_autompg, x_test_autompg, y_test_autompg)
# Out:
# training_data
# predict 25.20265 actual 27.0
# predict 19.343042 actual 22.0
# predict 25.25989 actual 25.0
# predict 30.908812 actual 30.0
# predict 23.222677 actual 26.8
# predict 25.20289 actual 26.0
# predict 31.403543 actual 35.7
# predict 19.67843 actual 21.0
# predict 30.709747 actual 30.0
# predict 34.08435 actual 31.8
# predict 25.158922 actual 30.0
# predict 14.672028 actual 15.0
# predict 36.849663 actual 39.0
# predict 36.772976 actual 36.0
# predict 29.79213 actual 31.0
# predict 14.260414 actual 14.0
# predict 32.716484 actual 29.8
# predict 19.304441 actual 19.0
# predict 19.113386 actual 16.0
# predict 15.083452 actual 17.5
# predict 13.33917 actual 13.0
# predict 30.65137 actual 28.0
# predict 13.440451 actual 14.0
# predict 14.405376 actual 14.0
# predict 25.52583 actual 27.9
# predict 22.763649 actual 20.8
# predict 19.790007 actual 20.5
# predict 25.478798 actual 22.3
# predict 25.189573 actual 24.0
# predict 26.030323 actual 27.0
# predict 11.568293 actual 10.0
# ...

# %%
print('training_data')
prediction_result_SSE_inverse(model_automobile, X_train_automobile, Y_train_automobile)
print('validation_data')
prediction_result_SSE_inverse(model_automobile, X_val_automobile, Y_val_automobile)
print('testing_data')
prediction_result_SSE_inverse(model_automobile, x_test_automobile, y_test_automobile)
# Out:
# training_data
# predict 14464.506 actual [12964.]
# predict 7672.65 actual [6918.]
# predict 7109.1567 actual [6529.]
# predict 9497.85 actual [9959.]
# predict 7112.966 actual [7129.]
# predict 12774.135 actual [9989.]
# predict 46988.344 actual [45400.]
# predict 8981.217 actual [10345.]
# predict 17966.97 actual [11900.]
# predict 30776.127 actual [32250.]
# predict 14948.25 actual [16925.]
# predict 13337.999 actual [13645.]
# predict 21673.084 actual [21485.]
# predict 7882.545 actual [7957.]
# predict 9205.473 actual [8949.]
# predict 6784.983 actual [7738.]
# predict 16879.182 actual [17450.]
# predict 8834.611 actual [7775.]
# predict 13336.1875 actual [11845.]
# predict 22366.875 actual [13207.]
# predict 22570.432 actual [22470.]
# predict 11864.682 actual [9980.]
# predict 8046.032 actual [8058.]
# predict 8000.963 actual [7295.]
# predict 12542.965 actual [11199.]
# predict 9743.412 actual [8948.]
# predict 14953.128 actual [15645.]
# predict 15493.842 actual [13200.]
# ...

# %%
print('training_data')
prediction_result_SSE(model_challenger, X_train_challenger, Y_train_challenger)
print('validation_data')
prediction_result_SSE(model_challenger, X_val_challenger, Y_val_challenger)
print('testing_data')
prediction_result_SSE(model_challenger, x_test_challenger, y_test_challenger)
# Out:
# training_data
# predict 5.999995 actual 6
# predict 6.000169 actual 6
# predict 5.999966 actual 6
# predict 6.0000854 actual 6
# predict 5.9991174 actual 6
# predict 5.999995 actual 6
# predict 6.000013 actual 6
# predict 6.0002413 actual 6
# predict 6.000243 actual 6
# predict 5.9993534 actual 6
# predict 5.999918 actual 6
# predict 6.000009 actual 6
# predict 5.9994593 actual 6
# predict 5.9994593 actual 6
# predict 5.9993496 actual 6
# predict 6.0002413 actual 6
# predict 5.9998074 actual 6
# predict 5.999974 actual 6
# predict 5.9998074 actual 6
# predict 5.9999204 actual 6
# predict 6.0003724 actual 6
# predict 6.0000854 actual 6
# predict 5.999457 actual 6
# predict 6.000169 actual 6
# predict 6.0001755 actual 6
# predict 5.9998684 actual 6
# predict 6.0003724 actual 6
# predict 6.0000525 actual 6
# predict 5.999457 actual 6
# predict 5.9993496 actual 6
# predict 5.9991174 actual 6
# predict 6.0001755 actual 6
# 2.3462550871045096e-06
# validation_data
# ...

# %%
model_airfoil.load_weights('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FA-MLP_model_airfoil_second_step_seed2.h5')
training=model_airfoil.evaluate(X_train_airfoil, Y_train_airfoil, verbose=0)
validating=model_airfoil.evaluate(X_val_airfoil, Y_val_airfoil, verbose=0)
testing=model_airfoil.evaluate(x_test_airfoil, y_test_airfoil, verbose=0)
print(training)
print(validating)
print(testing)
# Out:
# 6.381455042516324
# 6.656778206295438
# 6.451649589876158

# %%
model_autompg=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FA-MLP_model_autompg_second_step_seed2.h5')
training=model_autompg.evaluate(X_train_autompg, Y_train_autompg, verbose=0)
validating=model_autompg.evaluate(X_val_autompg, Y_val_autompg, verbose=0)
testing=model_autompg.evaluate(x_test_autompg, y_test_autompg, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 5.643127848632144
# validation 8.879271943690414
# testing 4.672389733589302

# %%
model_automobile=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FA-MLP_model_automobile_second_step_seed2.h5')
training=model_automobile.evaluate(X_train_automobile, Y_train_automobile, verbose=0)
validating=model_automobile.evaluate(X_val_automobile, Y_val_automobile, verbose=0)
testing=model_automobile.evaluate(x_test_automobile, y_test_automobile, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 0.004374518166654385
# validation 0.003192801959812641
# testing 0.004517759662121534

# %%
model_challenger=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FA-MLP_model_challenger_second_step_seed2.h5')
training=model_challenger.evaluate(X_train_challenger, Y_train_challenger, verbose=0)
validating=model_challenger.evaluate(X_val_challenger, Y_val_challenger, verbose=0)
testing=model_challenger.evaluate(x_test_challenger, y_test_challenger, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 2.915749348630925e-07
# validation 1.7850977584998873e-08
# testing 2.492132367137856e-08

# %%
print('training_data')
prediction_result_SSE(model_airfoil, X_train_airfoil, Y_train_airfoil)
print('validation_data')
prediction_result_SSE(model_airfoil, X_val_airfoil, Y_val_airfoil)
print('testing_data')
prediction_result_SSE(model_airfoil, x_test_airfoil, y_test_airfoil)
# Out:
# training_data
# predict 134.86813 actual 133.59799999999998
# predict 131.55011 actual 131.434
# predict 129.82286 actual 128.679
# predict 125.024765 actual 127.006
# predict 136.84294 actual 134.928
# predict 126.01375 actual 128.139
# predict 129.22272 actual 132.251
# predict 122.194534 actual 127.04
# predict 129.76106 actual 131.515
# predict 132.6571 actual 134.976
# predict 126.12515 actual 129.377
# predict 125.534256 actual 139.226
# predict 117.484146 actual 120.51299999999999
# predict 126.37622 actual 122.235
# predict 134.54861 actual 136.023
# predict 110.857605 actual 110.839
# predict 122.53427 actual 122.771
# predict 120.48445 actual 121.93299999999999
# predict 121.90015 actual 119.67
# predict 126.21344 actual 123.209
# predict 125.97067 actual 128.444
# predict 121.178604 actual 125.62700000000001
# predict 129.96538 actual 128.144
# predict 121.02872 actual 122.75399999999999
# predict 128.39886 actual 130.311
# predict 120.81055 actual 125.715
# ...

# %%
print('training_data')
prediction_result_SSE(model_autompg, X_train_autompg, Y_train_autompg)
print('validation_data')
prediction_result_SSE(model_autompg, X_val_autompg, Y_val_autompg)
print('testing_data')
prediction_result_SSE(model_autompg, x_test_autompg, y_test_autompg)
# Out:
# training_data
# predict 28.985329 actual 27.0
# predict 19.240005 actual 22.0
# predict 24.432148 actual 25.0
# predict 32.190025 actual 30.0
# predict 24.221958 actual 26.8
# predict 27.02856 actual 26.0
# predict 33.492355 actual 35.7
# predict 20.81677 actual 21.0
# predict 29.58902 actual 30.0
# predict 36.645878 actual 31.8
# predict 26.706873 actual 30.0
# predict 13.724568 actual 15.0
# predict 39.168728 actual 39.0
# predict 37.256252 actual 36.0
# predict 29.07196 actual 31.0
# predict 15.173021 actual 14.0
# predict 31.97114 actual 29.8
# predict 18.952795 actual 19.0
# predict 18.975739 actual 16.0
# predict 14.691988 actual 17.5
# predict 13.730736 actual 13.0
# predict 26.805668 actual 28.0
# predict 13.555418 actual 14.0
# predict 13.999792 actual 14.0
# predict 26.879267 actual 27.9
# predict 20.560595 actual 20.8
# predict 21.540075 actual 20.5
# predict 26.260107 actual 22.3
# predict 24.627598 actual 24.0
# predict 26.72963 actual 27.0
# ...

# %%
print('training_data')
prediction_result_SSE_inverse(model_automobile, X_train_automobile, Y_train_automobile)
print('validation_data')
prediction_result_SSE_inverse(model_automobile, X_val_automobile, Y_val_automobile)
print('testing_data')
prediction_result_SSE_inverse(model_automobile, x_test_automobile, y_test_automobile)
# Out:
# training_data
# predict 13444.5 actual [12964.]
# predict 6956.2256 actual [6918.]
# predict 6746.9766 actual [6529.]
# predict 9660.563 actual [9959.]
# predict 6759.296 actual [7129.]
# predict 12617.045 actual [9989.]
# predict 40462.965 actual [45400.]
# predict 8239.099 actual [10345.]
# predict 16387.229 actual [11900.]
# predict 32052.674 actual [32250.]
# predict 12723.683 actual [16925.]
# predict 13577.013 actual [13645.]
# predict 21125.486 actual [21485.]
# predict 8104.218 actual [7957.]
# predict 8389.934 actual [8949.]
# predict 6103.359 actual [7738.]
# predict 15793.966 actual [17450.]
# predict 9039.266 actual [7775.]
# predict 13552.806 actual [11845.]
# predict 22099.32 actual [13207.]
# predict 18861.111 actual [22470.]
# predict 9025.463 actual [9980.]
# predict 7714.3154 actual [8058.]
# predict 7073.7563 actual [7295.]
# predict 12986.98 actual [11199.]
# predict 8144.266 actual [8948.]
# predict 14900.496 actual [15645.]
# predict 15367.802 actual [13200.]
# ...

# %%
print('training_data')
prediction_result_SSE(model_challenger, X_train_challenger, Y_train_challenger)
print('validation_data')
prediction_result_SSE(model_challenger, X_val_challenger, Y_val_challenger)
print('testing_data')
prediction_result_SSE(model_challenger, x_test_challenger, y_test_challenger)
# Out:
# training_data
# predict 5.9998846 actual 6
# predict 6.0000277 actual 6
# predict 5.9999986 actual 6
# predict 6.0003715 actual 6
# predict 5.9997144 actual 6
# predict 5.9998846 actual 6
# predict 5.9999785 actual 6
# predict 6.0015707 actual 6
# predict 6.0001283 actual 6
# predict 6.00019 actual 6
# predict 5.9999294 actual 6
# predict 6.000377 actual 6
# predict 6.000287 actual 6
# predict 6.000287 actual 6
# predict 6.000166 actual 6
# predict 6.0015707 actual 6
# predict 6.0004683 actual 6
# predict 6.000159 actual 6
# predict 6.0004683 actual 6
# predict 6.0002093 actual 6
# predict 6.001072 actual 6
# predict 6.0003715 actual 6
# predict 6.000578 actual 6
# predict 6.0000277 actual 6
# predict 6.0000086 actual 6
# predict 5.9998555 actual 6
# predict 6.001072 actual 6
# predict 6.000119 actual 6
# predict 6.000578 actual 6
# predict 6.000166 actual 6
# predict 5.9997144 actual 6
# predict 6.0000086 actual 6
# 4.66519895780948e-06
# validation_data
# ...

# %%
model_airfoil.load_weights('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FA-MLP_model_airfoil_second_step_seed3.h5')
training=model_airfoil.evaluate(X_train_airfoil, Y_train_airfoil, verbose=0)
validating=model_airfoil.evaluate(X_val_airfoil, Y_val_airfoil, verbose=0)
testing=model_airfoil.evaluate(x_test_airfoil, y_test_airfoil, verbose=0)
print(training)
print(validating)
print(testing)
# Out:
# 6.472903452898613
# 7.891966087553236
# 6.497214140090267

# %%
model_autompg=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FA-MLP_model_autompg_second_step_seed3.h5')
training=model_autompg.evaluate(X_train_autompg, Y_train_autompg, verbose=0)
validating=model_autompg.evaluate(X_val_autompg, Y_val_autompg, verbose=0)
testing=model_autompg.evaluate(x_test_autompg, y_test_autompg, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 5.760337592911546
# validation 8.56739777225559
# testing 6.252329899092852

# %%
model_automobile=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FA-MLP_model_automobile_second_step_seed3.h5')
training=model_automobile.evaluate(X_train_automobile, Y_train_automobile, verbose=0)
validating=model_automobile.evaluate(X_val_automobile, Y_val_automobile, verbose=0)
testing=model_automobile.evaluate(x_test_automobile, y_test_automobile, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 0.002475804310630668
# validation 0.0031450996175408363
# testing 0.004380196798592806

# %%
model_challenger=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\FA-MLP_model_challenger_second_step_seed3.h5')
training=model_challenger.evaluate(X_train_challenger, Y_train_challenger, verbose=0)
validating=model_challenger.evaluate(X_val_challenger, Y_val_challenger, verbose=0)
testing=model_challenger.evaluate(x_test_challenger, y_test_challenger, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 1.7623347048356663e-07
# validation 2.8128852136433125e-08
# testing 2.6015056775463563e-08

# %%
print('training_data')
prediction_result_SSE(model_airfoil, X_train_airfoil, Y_train_airfoil)
print('validation_data')
prediction_result_SSE(model_airfoil, X_val_airfoil, Y_val_airfoil)
print('testing_data')
prediction_result_SSE(model_airfoil, x_test_airfoil, y_test_airfoil)
# Out:
# training_data
# predict 130.83435 actual 133.59799999999998
# predict 128.42694 actual 131.434
# predict 130.02695 actual 128.679
# predict 127.95897 actual 127.006
# predict 133.86646 actual 134.928
# predict 127.80998 actual 128.139
# predict 129.54883 actual 132.251
# predict 121.04451 actual 127.04
# predict 129.328 actual 131.515
# predict 135.0772 actual 134.976
# predict 131.23349 actual 129.377
# predict 128.7891 actual 139.226
# predict 116.930756 actual 120.51299999999999
# predict 126.47537 actual 122.235
# predict 135.46742 actual 136.023
# predict 110.67365 actual 110.839
# predict 124.10656 actual 122.771
# predict 122.42383 actual 121.93299999999999
# predict 120.4575 actual 119.67
# predict 126.63539 actual 123.209
# predict 124.39146 actual 128.444
# predict 123.89908 actual 125.62700000000001
# predict 129.51315 actual 128.144
# predict 120.873856 actual 122.75399999999999
# predict 131.41731 actual 130.311
# predict 118.96417 actual 125.715
# ...

# %%
print('training_data')
prediction_result_SSE(model_autompg, X_train_autompg, Y_train_autompg)
print('validation_data')
prediction_result_SSE(model_autompg, X_val_autompg, Y_val_autompg)
print('testing_data')
prediction_result_SSE(model_autompg, x_test_autompg, y_test_autompg)
# Out:
# training_data
# predict 24.847914 actual 27.0
# predict 20.857065 actual 22.0
# predict 25.097178 actual 25.0
# predict 30.883465 actual 30.0
# predict 23.765038 actual 26.8
# predict 24.126373 actual 26.0
# predict 33.99678 actual 35.7
# predict 19.87919 actual 21.0
# predict 29.823067 actual 30.0
# predict 35.904 actual 31.8
# predict 23.828453 actual 30.0
# predict 14.217378 actual 15.0
# predict 39.58221 actual 39.0
# predict 36.134964 actual 36.0
# predict 26.398806 actual 31.0
# predict 12.909471 actual 14.0
# predict 29.131708 actual 29.8
# predict 17.79659 actual 19.0
# predict 16.236889 actual 16.0
# predict 16.410957 actual 17.5
# predict 12.893266 actual 13.0
# predict 28.586178 actual 28.0
# predict 13.814349 actual 14.0
# predict 13.623058 actual 14.0
# predict 25.350391 actual 27.9
# predict 22.707481 actual 20.8
# predict 19.338554 actual 20.5
# predict 23.569223 actual 22.3
# predict 23.217258 actual 24.0
# predict 27.10439 actual 27.0
# predict 10.522436 actual 10.0
# ...

# %%
print('training_data')
prediction_result_SSE_inverse(model_automobile, X_train_automobile, Y_train_automobile)
print('validation_data')
prediction_result_SSE_inverse(model_automobile, X_val_automobile, Y_val_automobile)
print('testing_data')
prediction_result_SSE_inverse(model_automobile, x_test_automobile, y_test_automobile)
# Out:
# training_data
# predict 13999.715 actual [12964.]
# predict 8583.862 actual [6918.]
# predict 6520.1978 actual [6529.]
# predict 10193.931 actual [9959.]
# predict 6546.2983 actual [7129.]
# predict 12543.098 actual [9989.]
# predict 45663.383 actual [45400.]
# predict 7234.814 actual [10345.]
# predict 13580.577 actual [11900.]
# predict 30098.62 actual [32250.]
# predict 11871.534 actual [16925.]
# predict 13011.21 actual [13645.]
# predict 23222.17 actual [21485.]
# predict 8061.081 actual [7957.]
# predict 9153.617 actual [8949.]
# predict 8972.033 actual [7738.]
# predict 15515.63 actual [17450.]
# predict 9095.87 actual [7775.]
# predict 12997.085 actual [11845.]
# predict 16713.783 actual [13207.]
# predict 18393.027 actual [22470.]
# predict 8760.661 actual [9980.]
# predict 9288.599 actual [8058.]
# predict 8244.588 actual [7295.]
# predict 12820.154 actual [11199.]
# predict 9110.089 actual [8948.]
# predict 14679.288 actual [15645.]
# predict 15551.797 actual [13200.]
# ...

# %%
print('training_data')
prediction_result_SSE(model_challenger, X_train_challenger, Y_train_challenger)
print('validation_data')
prediction_result_SSE(model_challenger, X_val_challenger, Y_val_challenger)
print('testing_data')
prediction_result_SSE(model_challenger, x_test_challenger, y_test_challenger)
# Out:
# training_data
# predict 5.999692 actual 6
# predict 6.0000744 actual 6
# predict 5.99973 actual 6
# predict 6.000346 actual 6
# predict 6.000824 actual 6
# predict 5.999692 actual 6
# predict 6.0000086 actual 6
# predict 5.9998903 actual 6
# predict 5.9990654 actual 6
# predict 5.999978 actual 6
# predict 5.999958 actual 6
# predict 5.999798 actual 6
# predict 5.99959 actual 6
# predict 5.99959 actual 6
# predict 6.0000544 actual 6
# predict 5.9998903 actual 6
# predict 5.9990396 actual 6
# predict 5.9997644 actual 6
# predict 5.9990396 actual 6
# predict 6.000085 actual 6
# predict 6.000432 actual 6
# predict 6.000346 actual 6
# predict 6.000086 actual 6
# predict 6.0000744 actual 6
# predict 6.000066 actual 6
# predict 5.9995823 actual 6
# predict 6.000432 actual 6
# predict 6.000083 actual 6
# predict 6.000086 actual 6
# predict 6.0000544 actual 6
# predict 6.000824 actual 6
# predict 6.000066 actual 6
# 2.819735527737066e-06
# validation_data
# predict 6.000066 actual 6
# ...

# %% [markdown]
# # CS-MLP

# %%
model_airfoil=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\CS-MLP_model_airfoil_second_step.h5')
training=model_airfoil.evaluate(X_train_airfoil, Y_train_airfoil, verbose=0)
validating=model_airfoil.evaluate(X_val_airfoil, Y_val_airfoil, verbose=0)
testing=model_airfoil.evaluate(x_test_airfoil, y_test_airfoil, verbose=0)
print(training)
print(validating)
print(testing)
# Out:
# 7.253168557533293
# 8.744606447219848
# 7.2012601742702245

# %%
model_autompg=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\CS-MLP_model_autompg_second_step.h5')
training=model_autompg.evaluate(X_train_autompg, Y_train_autompg, verbose=0)
validating=model_autompg.evaluate(X_val_autompg, Y_val_autompg, verbose=0)
testing=model_autompg.evaluate(x_test_autompg, y_test_autompg, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 7.952809386009718
# validation 10.824202246585134
# testing 6.211369304333703

# %%
model_automobile=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\CS-MLP_model_automobile_second_step.h5')
training=model_automobile.evaluate(X_train_automobile, Y_train_automobile, verbose=0)
validating=model_automobile.evaluate(X_val_automobile, Y_val_automobile, verbose=0)
testing=model_automobile.evaluate(x_test_automobile, y_test_automobile, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 0.002689241299770408
# validation 0.002638569800183177
# testing 0.004596528597176075

# %%
model_challenger=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\CS-MLP_model_challenger_second_step.h5')
training=model_challenger.evaluate(X_train_challenger, Y_train_challenger, verbose=0)
validating=model_challenger.evaluate(X_val_challenger, Y_val_challenger, verbose=0)
testing=model_challenger.evaluate(x_test_challenger, y_test_challenger, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# WARNING:tensorflow:From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# training 1.8695849576033652e-05
# validation 8.12418875284493e-06
# testing 6.9044658630446065e-06

# %%
print('training_data')
prediction_result_SSE(model_airfoil, X_train_airfoil, Y_train_airfoil)
print('validation_data')
prediction_result_SSE(model_airfoil, X_val_airfoil, Y_val_airfoil)
print('testing_data')
prediction_result_SSE(model_airfoil, x_test_airfoil, y_test_airfoil)
# Out:
# training_data
# predict 133.6146 actual 133.59799999999998
# predict 131.99918 actual 131.434
# predict 128.36877 actual 128.679
# predict 124.190216 actual 127.006
# predict 134.67389 actual 134.928
# predict 126.67429 actual 128.139
# predict 128.07413 actual 132.251
# predict 125.44957 actual 127.04
# predict 130.9123 actual 131.515
# predict 137.2652 actual 134.976
# predict 127.43542 actual 129.377
# predict 125.0882 actual 139.226
# predict 116.18529 actual 120.51299999999999
# predict 126.36893 actual 122.235
# predict 134.07285 actual 136.023
# predict 110.10493 actual 110.839
# predict 122.57441 actual 122.771
# predict 120.10569 actual 121.93299999999999
# predict 121.14704 actual 119.67
# predict 125.37805 actual 123.209
# predict 123.971504 actual 128.444
# predict 121.05239 actual 125.62700000000001
# predict 128.04184 actual 128.144
# predict 121.64614 actual 122.75399999999999
# predict 131.79385 actual 130.311
# predict 121.33999 actual 125.715
# ...

# %%
print('training_data')
prediction_result_SSE(model_autompg, X_train_autompg, Y_train_autompg)
print('validation_data')
prediction_result_SSE(model_autompg, X_val_autompg, Y_val_autompg)
print('testing_data')
prediction_result_SSE(model_autompg, x_test_autompg, y_test_autompg)
# Out:
# training_data
# predict 25.643774 actual 27.0
# predict 21.00585 actual 22.0
# predict 24.185698 actual 25.0
# predict 30.9749 actual 30.0
# predict 23.878014 actual 26.8
# predict 25.093185 actual 26.0
# predict 32.9959 actual 35.7
# predict 20.570004 actual 21.0
# predict 28.901073 actual 30.0
# predict 33.638123 actual 31.8
# predict 28.466192 actual 30.0
# predict 14.876931 actual 15.0
# predict 35.013653 actual 39.0
# predict 31.519249 actual 36.0
# predict 27.710756 actual 31.0
# predict 14.887608 actual 14.0
# predict 32.168713 actual 29.8
# predict 17.42658 actual 19.0
# predict 19.837368 actual 16.0
# predict 14.871867 actual 17.5
# predict 14.240932 actual 13.0
# predict 24.439426 actual 28.0
# predict 14.746876 actual 14.0
# predict 14.8767185 actual 14.0
# predict 27.296082 actual 27.9
# predict 21.853981 actual 20.8
# predict 22.133492 actual 20.5
# predict 26.666475 actual 22.3
# predict 24.43945 actual 24.0
# predict 29.383564 actual 27.0
# ...

# %%
print('training_data')
prediction_result_SSE_inverse(model_automobile, X_train_automobile, Y_train_automobile)
print('validation_data')
prediction_result_SSE_inverse(model_automobile, X_val_automobile, Y_val_automobile)
print('testing_data')
prediction_result_SSE_inverse(model_automobile, x_test_automobile, y_test_automobile)
# Out:
# training_data
# predict 12450.548 actual [12964.]
# predict 8276.705 actual [6918.]
# predict 7252.669 actual [6529.]
# predict 8799.383 actual [9959.]
# predict 7277.0127 actual [7129.]
# predict 13261.947 actual [9989.]
# predict 46083.523 actual [45400.]
# predict 9392.179 actual [10345.]
# predict 16611.639 actual [11900.]
# predict 32046.201 actual [32250.]
# predict 14494.923 actual [16925.]
# predict 12518.957 actual [13645.]
# predict 24262.053 actual [21485.]
# predict 8226.553 actual [7957.]
# predict 10488.977 actual [8949.]
# predict 9506.192 actual [7738.]
# predict 13920.5205 actual [17450.]
# predict 7464.643 actual [7775.]
# predict 12505.355 actual [11845.]
# predict 16784.91 actual [13207.]
# predict 21953.127 actual [22470.]
# predict 10525.411 actual [9980.]
# predict 7252.405 actual [8058.]
# predict 8723.693 actual [7295.]
# predict 13579.011 actual [11199.]
# predict 9726.028 actual [8948.]
# predict 14727.627 actual [15645.]
# predict 17578.53 actual [13200.]
# ...

# %%
print('training_data')
prediction_result_SSE(model_challenger, X_train_challenger, Y_train_challenger)
print('validation_data')
prediction_result_SSE(model_challenger, X_val_challenger, Y_val_challenger)
print('testing_data')
prediction_result_SSE(model_challenger, x_test_challenger, y_test_challenger)
# Out:
# training_data
# predict 5.997306 actual 6
# predict 5.99986 actual 6
# predict 5.9974785 actual 6
# predict 6.008301 actual 6
# predict 6.0050974 actual 6
# predict 5.997306 actual 6
# predict 5.996722 actual 6
# predict 5.997423 actual 6
# predict 5.9871216 actual 6
# predict 5.9971886 actual 6
# predict 6.0045414 actual 6
# predict 5.997772 actual 6
# predict 6.0023184 actual 6
# predict 6.0023184 actual 6
# predict 5.994466 actual 6
# predict 5.997423 actual 6
# predict 6.005993 actual 6
# predict 5.997633 actual 6
# predict 6.005993 actual 6
# predict 6.0004396 actual 6
# predict 5.998254 actual 6
# predict 6.008301 actual 6
# predict 6.0005836 actual 6
# predict 5.99986 actual 6
# predict 5.9994717 actual 6
# predict 6.002673 actual 6
# predict 5.998254 actual 6
# predict 6.0003138 actual 6
# predict 6.0005836 actual 6
# predict 5.994466 actual 6
# predict 6.0050974 actual 6
# predict 5.9994717 actual 6
# 0.00029913356411270797
# validation_data
# predict 5.9994717 actual 6
# ...

# %%
model_airfoil=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\CS-MLP_model_airfoil_second_step_seed2.h5')
training=model_airfoil.evaluate(X_train_airfoil, Y_train_airfoil, verbose=0)
validating=model_airfoil.evaluate(X_val_airfoil, Y_val_airfoil, verbose=0)
testing=model_airfoil.evaluate(x_test_airfoil, y_test_airfoil, verbose=0)
print(training)
print(validating)
print(testing)
# Out:
# 7.710427936945578
# 9.427696754667494
# 7.928339907553344

# %%
model_autompg=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\CS-MLP_model_autompg_second_step_seed2.h5')
training=model_autompg.evaluate(X_train_autompg, Y_train_autompg, verbose=0)
validating=model_autompg.evaluate(X_val_autompg, Y_val_autompg, verbose=0)
testing=model_autompg.evaluate(x_test_autompg, y_test_autompg, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 5.6987920747186145
# validation 8.855446532621222
# testing 6.771928035606773

# %%
model_automobile=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\CS-MLP_model_automobile_second_step_seed2.h5')
training=model_automobile.evaluate(X_train_automobile, Y_train_automobile, verbose=0)
validating=model_automobile.evaluate(X_val_automobile, Y_val_automobile, verbose=0)
testing=model_automobile.evaluate(x_test_automobile, y_test_automobile, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 0.0016541979975763944
# validation 0.0025951021816581488
# testing 0.007247183471918106

# %%
model_challenger=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\CS-MLP_model_challenger_second_step_seed2.h5')
training=model_challenger.evaluate(X_train_challenger, Y_train_challenger, verbose=0)
validating=model_challenger.evaluate(X_val_challenger, Y_val_challenger, verbose=0)
testing=model_challenger.evaluate(x_test_challenger, y_test_challenger, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 0.0011198242427781224
# validation 0.0004538508947007358
# testing 0.0005701246554963291

# %%
print('training_data')
prediction_result_SSE(model_airfoil, X_train_airfoil, Y_train_airfoil)
print('validation_data')
prediction_result_SSE(model_airfoil, X_val_airfoil, Y_val_airfoil)
print('testing_data')
prediction_result_SSE(model_airfoil, x_test_airfoil, y_test_airfoil)
# Out:
# training_data
# predict 134.76971 actual 133.59799999999998
# predict 130.14145 actual 131.434
# predict 128.9925 actual 128.679
# predict 125.75871 actual 127.006
# predict 135.3223 actual 134.928
# predict 127.032074 actual 128.139
# predict 129.55304 actual 132.251
# predict 125.70763 actual 127.04
# predict 129.1865 actual 131.515
# predict 137.11285 actual 134.976
# predict 128.904 actual 129.377
# predict 125.8686 actual 139.226
# predict 118.4154 actual 120.51299999999999
# predict 127.68257 actual 122.235
# predict 133.50932 actual 136.023
# predict 112.07767 actual 110.839
# predict 124.06595 actual 122.771
# predict 123.0134 actual 121.93299999999999
# predict 120.447624 actual 119.67
# predict 124.7133 actual 123.209
# predict 124.17871 actual 128.444
# predict 123.8156 actual 125.62700000000001
# predict 126.47211 actual 128.144
# predict 121.08425 actual 122.75399999999999
# predict 132.1155 actual 130.311
# predict 123.05905 actual 125.715
# ...

# %%
print('training_data')
prediction_result_SSE(model_autompg, X_train_autompg, Y_train_autompg)
print('validation_data')
prediction_result_SSE(model_autompg, X_val_autompg, Y_val_autompg)
print('testing_data')
prediction_result_SSE(model_autompg, x_test_autompg, y_test_autompg)
# Out:
# training_data
# predict 24.526907 actual 27.0
# predict 18.982246 actual 22.0
# predict 24.39065 actual 25.0
# predict 30.16731 actual 30.0
# predict 21.60432 actual 26.8
# predict 23.83026 actual 26.0
# predict 32.558617 actual 35.7
# predict 18.221405 actual 21.0
# predict 28.375854 actual 30.0
# predict 34.856407 actual 31.8
# predict 26.855831 actual 30.0
# predict 14.731214 actual 15.0
# predict 37.841766 actual 39.0
# predict 38.19208 actual 36.0
# predict 26.406158 actual 31.0
# predict 13.423041 actual 14.0
# predict 28.747711 actual 29.8
# predict 18.262087 actual 19.0
# predict 15.073466 actual 16.0
# predict 14.869291 actual 17.5
# predict 13.045278 actual 13.0
# predict 25.412226 actual 28.0
# predict 14.004864 actual 14.0
# predict 14.206193 actual 14.0
# predict 26.698614 actual 27.9
# predict 21.629147 actual 20.8
# predict 20.316355 actual 20.5
# predict 25.387947 actual 22.3
# predict 23.23245 actual 24.0
# predict 24.616278 actual 27.0
# ...

# %%
print('training_data')
prediction_result_SSE_inverse(model_automobile, X_train_automobile, Y_train_automobile)
print('validation_data')
prediction_result_SSE_inverse(model_automobile, X_val_automobile, Y_val_automobile)
print('testing_data')
prediction_result_SSE_inverse(model_automobile, x_test_automobile, y_test_automobile)
# Out:
# training_data
# predict 13707.722 actual [12964.]
# predict 6318.933 actual [6918.]
# predict 6579.8154 actual [6529.]
# predict 10787.934 actual [9959.]
# predict 6568.2534 actual [7129.]
# predict 12197.975 actual [9989.]
# predict 44051.67 actual [45400.]
# predict 7909.2676 actual [10345.]
# predict 14883.023 actual [11900.]
# predict 33518.49 actual [32250.]
# predict 15474.561 actual [16925.]
# predict 12751.43 actual [13645.]
# predict 23847.629 actual [21485.]
# predict 7258.189 actual [7957.]
# predict 8603.325 actual [8949.]
# predict 6991.1084 actual [7738.]
# predict 16282.433 actual [17450.]
# predict 8470.432 actual [7775.]
# predict 12760.59 actual [11845.]
# predict 15984.518 actual [13207.]
# predict 22446.254 actual [22470.]
# predict 10555.469 actual [9980.]
# predict 6651.3003 actual [8058.]
# predict 7074.422 actual [7295.]
# predict 12321.419 actual [11199.]
# predict 10486.641 actual [8948.]
# predict 16380.403 actual [15645.]
# ...

# %%
print('training_data')
prediction_result_SSE(model_challenger, X_train_challenger, Y_train_challenger)
print('validation_data')
prediction_result_SSE(model_challenger, X_val_challenger, Y_val_challenger)
print('testing_data')
prediction_result_SSE(model_challenger, x_test_challenger, y_test_challenger)
# Out:
# training_data
# predict 6.0186315 actual 6
# predict 6.000243 actual 6
# predict 6.0249977 actual 6
# predict 5.9370537 actual 6
# predict 5.9906445 actual 6
# predict 6.0186315 actual 6
# predict 6.0135164 actual 6
# predict 6.052743 actual 6
# predict 6.045744 actual 6
# predict 5.995139 actual 6
# predict 6.00506 actual 6
# predict 6.044039 actual 6
# predict 6.0425816 actual 6
# predict 6.0425816 actual 6
# predict 6.042134 actual 6
# predict 6.052743 actual 6
# predict 5.9994874 actual 6
# predict 6.034902 actual 6
# predict 5.9994874 actual 6
# predict 5.9672375 actual 6
# predict 5.9518347 actual 6
# predict 5.9370537 actual 6
# predict 6.0120106 actual 6
# predict 6.000243 actual 6
# predict 6.0127316 actual 6
# predict 5.9664764 actual 6
# predict 5.9518347 actual 6
# predict 5.9727454 actual 6
# predict 6.0120106 actual 6
# predict 6.042134 actual 6
# predict 5.9906445 actual 6
# predict 6.0127316 actual 6
# 0.01791718602180481
# validation_data
# ...

# %%
model_airfoil=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\CS-MLP_model_airfoil_second_step_seed3.h5')
training=model_airfoil.evaluate(X_train_airfoil, Y_train_airfoil, verbose=0)
validating=model_airfoil.evaluate(X_val_airfoil, Y_val_airfoil, verbose=0)
testing=model_airfoil.evaluate(x_test_airfoil, y_test_airfoil, verbose=0)
print(training)
print(validating)
print(testing)
# Out:
# 8.016388265805553
# 10.163223842514887
# 7.445154046590349

# %%
model_autompg=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\CS-MLP_model_autompg_second_step_seed3.h5')
training=model_autompg.evaluate(X_train_autompg, Y_train_autompg, verbose=0)
validating=model_autompg.evaluate(X_val_autompg, Y_val_autompg, verbose=0)
testing=model_autompg.evaluate(x_test_autompg, y_test_autompg, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 6.488385882690875
# validation 9.807536391888634
# testing 6.575642371581773

# %%
model_automobile=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\CS-MLP_model_automobile_second_step_seed3.h5')
training=model_automobile.evaluate(X_train_automobile, Y_train_automobile, verbose=0)
validating=model_automobile.evaluate(X_val_automobile, Y_val_automobile, verbose=0)
testing=model_automobile.evaluate(x_test_automobile, y_test_automobile, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 0.0014872861817687541
# validation 0.0029376279562711716
# testing 0.007913337089121342

# %%
model_challenger=models.load_model('C:\\Users\\user\\Desktop\\Thesis\\model_weights\\CS-MLP_model_challenger_second_step_seed3.h5')
training=model_challenger.evaluate(X_train_challenger, Y_train_challenger, verbose=0)
validating=model_challenger.evaluate(X_val_challenger, Y_val_challenger, verbose=0)
testing=model_challenger.evaluate(x_test_challenger, y_test_challenger, verbose=0)
print('training', training)
print('validation', validating)
print('testing', testing)
# Out:
# training 6.157327152322978e-05
# validation 5.343747398001142e-05
# testing 8.405993139604107e-05

# %%
print('training_data')
prediction_result_SSE(model_airfoil, X_train_airfoil, Y_train_airfoil)
print('validation_data')
prediction_result_SSE(model_airfoil, X_val_airfoil, Y_val_airfoil)
print('testing_data')
prediction_result_SSE(model_airfoil, x_test_airfoil, y_test_airfoil)
# Out:
# training_data
# predict 132.75917 actual 133.59799999999998
# predict 131.60652 actual 131.434
# predict 128.80429 actual 128.679
# predict 125.789246 actual 127.006
# predict 133.59288 actual 134.928
# predict 126.347496 actual 128.139
# predict 128.64632 actual 132.251
# predict 126.95746 actual 127.04
# predict 129.89125 actual 131.515
# predict 138.68861 actual 134.976
# predict 127.97955 actual 129.377
# predict 124.58083 actual 139.226
# predict 119.43425 actual 120.51299999999999
# predict 125.217384 actual 122.235
# predict 134.46191 actual 136.023
# predict 111.45247 actual 110.839
# predict 122.69636 actual 122.771
# predict 118.250145 actual 121.93299999999999
# predict 121.368904 actual 119.67
# predict 126.46051 actual 123.209
# predict 123.58311 actual 128.444
# predict 121.53962 actual 125.62700000000001
# predict 130.70537 actual 128.144
# predict 122.66793 actual 122.75399999999999
# predict 130.10507 actual 130.311
# predict 125.50376 actual 125.715
# ...

# %%
print('training_data')
prediction_result_SSE(model_autompg, X_train_autompg, Y_train_autompg)
print('validation_data')
prediction_result_SSE(model_autompg, X_val_autompg, Y_val_autompg)
print('testing_data')
prediction_result_SSE(model_autompg, x_test_autompg, y_test_autompg)
# Out:
# training_data
# predict 24.62801 actual 27.0
# predict 19.626163 actual 22.0
# predict 24.328852 actual 25.0
# predict 29.382498 actual 30.0
# predict 21.901201 actual 26.8
# predict 24.03507 actual 26.0
# predict 30.220726 actual 35.7
# predict 18.685106 actual 21.0
# predict 27.37375 actual 30.0
# predict 35.923073 actual 31.8
# predict 24.050589 actual 30.0
# predict 13.894342 actual 15.0
# predict 35.4801 actual 39.0
# predict 36.774616 actual 36.0
# predict 26.48407 actual 31.0
# predict 15.25779 actual 14.0
# predict 30.026125 actual 29.8
# predict 20.330511 actual 19.0
# predict 17.642675 actual 16.0
# predict 16.931475 actual 17.5
# predict 13.901706 actual 13.0
# predict 25.54966 actual 28.0
# predict 13.809294 actual 14.0
# predict 13.884997 actual 14.0
# predict 26.654188 actual 27.9
# predict 22.182226 actual 20.8
# predict 21.044428 actual 20.5
# predict 25.515848 actual 22.3
# predict 24.075453 actual 24.0
# predict 25.103327 actual 27.0
# predict 13.808468 actual 10.0
# ...

# %%
print('training_data')
prediction_result_SSE_inverse(model_automobile, X_train_automobile, Y_train_automobile)
print('validation_data')
prediction_result_SSE_inverse(model_automobile, X_val_automobile, Y_val_automobile)
print('testing_data')
prediction_result_SSE_inverse(model_automobile, x_test_automobile, y_test_automobile)
# Out:
# training_data
# predict 13661.531 actual [12964.]
# predict 6417.548 actual [6918.]
# predict 7416.0615 actual [6529.]
# predict 9309.012 actual [9959.]
# predict 7492.4824 actual [7129.]
# predict 12734.388 actual [9989.]
# predict 44664.87 actual [45400.]
# predict 9349.69 actual [10345.]
# predict 13910.07 actual [11900.]
# predict 32465.098 actual [32250.]
# predict 14884.731 actual [16925.]
# predict 12718.113 actual [13645.]
# predict 24025.83 actual [21485.]
# predict 8738.086 actual [7957.]
# predict 9427.459 actual [8949.]
# predict 9285.468 actual [7738.]
# predict 16094.285 actual [17450.]
# predict 6775.1094 actual [7775.]
# predict 12686.847 actual [11845.]
# predict 14883.732 actual [13207.]
# predict 23257.768 actual [22470.]
# predict 10576.41 actual [9980.]
# predict 8376.428 actual [8058.]
# predict 8593.519 actual [7295.]
# predict 13565.305 actual [11199.]
# predict 9482.677 actual [8948.]
# predict 15040.51 actual [15645.]
# predict 16584.621 actual [13200.]
# ...

# %%
print('training_data')
prediction_result_SSE(model_challenger, X_train_challenger, Y_train_challenger)
print('validation_data')
prediction_result_SSE(model_challenger, X_val_challenger, Y_val_challenger)
print('testing_data')
prediction_result_SSE(model_challenger, x_test_challenger, y_test_challenger)
# Out:
# training_data
# predict 6.009729 actual 6
# predict 6.0038877 actual 6
# predict 6.0099483 actual 6
# predict 6.0128703 actual 6
# predict 5.999471 actual 6
# predict 6.009729 actual 6
# predict 6.0091147 actual 6
# predict 6.0126834 actual 6
# predict 5.999355 actual 6
# predict 6.0057826 actual 6
# predict 5.9880557 actual 6
# predict 6.0111766 actual 6
# predict 6.001467 actual 6
# predict 6.001467 actual 6
# predict 6.005935 actual 6
# predict 6.0126834 actual 6
# predict 5.9966483 actual 6
# predict 6.0104194 actual 6
# predict 5.9966483 actual 6
# predict 6.0031657 actual 6
# predict 6.012428 actual 6
# predict 6.0128703 actual 6
# predict 6.0031266 actual 6
# predict 6.0038877 actual 6
# predict 6.0049205 actual 6
# predict 6.0032516 actual 6
# predict 6.012428 actual 6
# predict 6.003238 actual 6
# predict 6.0031266 actual 6
# predict 6.005935 actual 6
# predict 5.999471 actual 6
# predict 6.0049205 actual 6
# 0.0009851723443716764
# validation_data
# ...
